# %% [markdown]
# # 2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2_rep1

# %% [markdown]
# Brief experiment description:
#
# * 1:150 1.5 hours, 1:750 5 hours, 100 into 200 uL PBS for cyt.
# * Testing relative levels of RPU construct in each landing pad
# * All strains are sequence confirmed
#
# Experimental variables:
# * Which landing pad contains PJ23101-YFP
#     - determined by strain number
#
# Notes on experiment:
#
# * FITC-A is the output channel (YFP)

# %% [markdown]
# ### Strains
#
# #### Experiment
# | strain number | parent strain | Description               |
# |---------------|---------------|-------------------------------|
# | AJT472  | EcN | PJ23101-YFP in LPattB5     |
# | AJT473  | EcN | PJ23101-YFP in LPattB2     |
# | AJT474  | EcN | PJ23101-YFP in LPattB7     |

# %% [markdown]
# ### Protocol
#
#  - Overnight in M9 + kan
#  - M9
#      * Dilute 1:150 in 500 uL deep-well plate, grow for 1.5 hours
#      * Dilute 1:750 into 500 uL in deep-well plate, grow for 5 hours
#          - cells were a little dilute at end
#      * 100 uL culture into 200 uL PBS + kan

# %%
# Matplotlib interactivity
#matplotlib notebook
import matplotlib
matplotlib.rc('figure', dpi = 160)
matplotlib.rcParams['pdf.fonttype'] = 42 # for making font editable when exported to PDF for Illustrator
matplotlib.rcParams['ps.fonttype'] = 42 # for making font editable when exported to PS for Illustrator

# Set the default sans-serif font to Arial"
matplotlib.rcParams['font.sans-serif'] = "Arial"
# Set to always use sans-serif fonts
matplotlib.rcParams['font.family'] = "sans-serif"

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import sys
import cytoflow as flow
import string
import pandas as pd
import pickle
from scipy.optimize import least_squares
from matplotlib.lines import Line2D

# Dan's custom scripts that aid in importing from conditions.csv file
sys.path.append('/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/cytoflow_example_fromDan/modules')
import cf_imports
import cf_helpers

# %%
# Import reloads for when modules are being changed
import importlib
importlib.reload(cf_imports)
importlib.reload(cf_helpers)
# Out:
# <module 'cf_helpers' from '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/cytoflow_example_fromDan/modules/cf_helpers.py'>

# %% [markdown]
# ## Data Import

# %%
# Provide full path to flow cytometry .fcs file directory and pass to fixer
fcs_dir = cf_imports.dir_fix(
    r'/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2')
# Optional specification of conditions directory (default to same directory as data)
conds_dir = None

# %%
# Create experiment from fcs files and conditions file ()
exp = cf_imports.exp_from_dirs(fcs_dir, conds_dir)
# Out:
# ['/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A1_A01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A2_A02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A3_A03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A4_A04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A5_A05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A6_A06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A7_A07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A8_A08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A9_A09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_A10_A10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_B1_B01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_B2_B02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_B3_B03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_B4_B04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C1_C01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C2_C02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C3_C03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C4_C04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C5_C05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C6_C06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C7_C07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C8_C08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C9_C09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_rep1/2021-01-12_EcN_LPs_RelativeExpression_M9_300minInduction_AJT472_473_474_476-1_2/Specimen_001_C10_C10.fcs']

# %%
# Check dataframe 
exp.data.head(10)
# exp2.data.head(10)
# exp3.data.head(10)
# Out:
#         FITC-A  FITC-H         FSC-A    FSC-H  PE-Texas Red-A  PE-Texas Red-H  \
# 0   -11.160000    60.0   5498.400391   2560.0       18.500000            36.0
# 1    26.040001    69.0   5357.780273   2344.0      -13.320000            24.0
# 2  1714.920044  1632.0  16505.470703  10393.0       37.740002            47.0
# 3     2.790000    55.0   4921.700195   2922.0       19.240000            44.0
# 4  1029.510010  1033.0  16388.550781  10901.0      -35.520000            19.0
# 5  1707.479980  1519.0  13313.870117   7747.0      -37.740002            21.0
# 6  1570.770020  1661.0  14501.240234   8385.0      -24.420000            17.0
# 7   -79.980003    42.0   4863.240234   3210.0       -5.180000            47.0
# 8  1177.380005  1044.0  15081.100586   8681.0       -4.440000            33.0
# 9   -84.629997    27.0   5285.100098   2743.0      -26.639999            37.0
#
#    Pacific Blue-A  Pacific Blue-H         SSC-A    SSC-H       Time col  iptg  \
# 0       -4.080000            68.0   2028.329956   1724.0  51.400002   1   0.0
# 1      -41.820000            28.0   1114.140015    801.0  51.500000   1   0.0
# 2       49.980000            63.0  45882.480469  43252.0  51.500000   1   0.0
# 3       96.900002            60.0   1402.440063   1191.0  51.500000   1   0.0
# 4       62.219997            51.0  31420.050781  29433.0  51.599998   1   0.0
# 5       21.420000            53.0  51801.929688  46495.0  51.599998   1   0.0
# 6       88.739998            53.0  46925.011719  42937.0  51.700001   1   0.0
# 7       29.580000            56.0    842.580017    925.0  51.700001   1   0.0
# 8      -39.779999            37.0  35993.789062  32921.0  51.700001   1   0.0
# 9       -2.040000            49.0   5604.180176   5647.0  51.700001   1   0.0
#
#   media parent_strain replicate row  sample_num strain_num
# 0    M9           EcN         1   A           1   AJT472-1
# 1    M9           EcN         1   A           1   AJT472-1
# 2    M9           EcN         1   A           1   AJT472-1
# 3    M9           EcN         1   A           1   AJT472-1
# 4    M9           EcN         1   A           1   AJT472-1
# 5    M9           EcN         1   A           1   AJT472-1
# 6    M9           EcN         1   A           1   AJT472-1
# 7    M9           EcN         1   A           1   AJT472-1
# 8    M9           EcN         1   A           1   AJT472-1
# 9    M9           EcN         1   A           1   AJT472-1

# %%
exp.data.groupby(['parent_strain','strain_num', 'iptg']).size()
# exp2.data.groupby(['parent_strain','strain_num', 'iptg']).size()
# exp3.data.groupby(['parent_strain','strain_num', 'iptg']).size()
# Out:
# parent_strain  strain_num  iptg
# EcN            AJT474      0.0     60930
#                AJT473-1    0.0     65751
#                AJT476-1b   0.0      8440
#                AJT476-2b   0.0     10253
#                AJT474-1    0.0     60387
#                AJT472      0.0     63002
#                AJT476-2a   0.0      6919
#                AJT476-1a   0.0      5897
#                AJT472-1    0.0     98952
#                blank       0.0     48400
#                AJT473      0.0     52855
# dtype: int64

# %% [markdown]
# ## Gating

# %% [markdown]
# ### FSC / SSC

# %%
scatter = flow.DensityView(
    xchannel = "FSC-H",
    ychannel = "SSC-H",
    yscale = "log",
    xscale = "log")

scatter.plot(exp, ylim=(100,100000))

# %% [markdown]
# Gate FSC-A / SSC-A w/ Guassian w/ 2 sigma stddeviation

# %%
g2 = flow.PolygonOp(name = "Debris_Filter",
                    xchannel = "FSC-H",
                    ychannel = "SSC-H",
                    xscale = 'log',
                    yscale = 'log')

g2.vertices = [(4000, 10000), # bottom left
             (18000, 18000), # bottom right
             (18000, 55000), # top right
             (4000, 35000)] # top left

# %%
# for polygon gating as opposed to using Gaussian mixture model
exp_gated = g2.apply(exp)

# %%
# takes a minute or two to run
g2.default_view().plot(exp_gated, alpha = 0.002)

# %%
exp_gated.data.head(10)
# exp2_gated.data.head(10)
# exp3_gated.data.head(10)
# Out:
#         FITC-A  FITC-H         FSC-A    FSC-H  PE-Texas Red-A  PE-Texas Red-H  \
# 0   -11.160000    60.0   5498.400391   2560.0       18.500000            36.0
# 1    26.040001    69.0   5357.780273   2344.0      -13.320000            24.0
# 2  1714.920044  1632.0  16505.470703  10393.0       37.740002            47.0
# 3     2.790000    55.0   4921.700195   2922.0       19.240000            44.0
# 4  1029.510010  1033.0  16388.550781  10901.0      -35.520000            19.0
# 5  1707.479980  1519.0  13313.870117   7747.0      -37.740002            21.0
# 6  1570.770020  1661.0  14501.240234   8385.0      -24.420000            17.0
# 7   -79.980003    42.0   4863.240234   3210.0       -5.180000            47.0
# 8  1177.380005  1044.0  15081.100586   8681.0       -4.440000            33.0
# 9   -84.629997    27.0   5285.100098   2743.0      -26.639999            37.0
#
#    Pacific Blue-A  Pacific Blue-H         SSC-A    SSC-H       Time col  iptg  \
# 0       -4.080000            68.0   2028.329956   1724.0  51.400002   1   0.0
# 1      -41.820000            28.0   1114.140015    801.0  51.500000   1   0.0
# 2       49.980000            63.0  45882.480469  43252.0  51.500000   1   0.0
# 3       96.900002            60.0   1402.440063   1191.0  51.500000   1   0.0
# 4       62.219997            51.0  31420.050781  29433.0  51.599998   1   0.0
# 5       21.420000            53.0  51801.929688  46495.0  51.599998   1   0.0
# 6       88.739998            53.0  46925.011719  42937.0  51.700001   1   0.0
# 7       29.580000            56.0    842.580017    925.0  51.700001   1   0.0
# 8      -39.779999            37.0  35993.789062  32921.0  51.700001   1   0.0
# 9       -2.040000            49.0   5604.180176   5647.0  51.700001   1   0.0
#
#   media parent_strain replicate row  sample_num strain_num  Debris_Filter
# 0    M9           EcN         1   A           1   AJT472-1          False
# 1    M9           EcN         1   A           1   AJT472-1          False
# 2    M9           EcN         1   A           1   AJT472-1           True
# 3    M9           EcN         1   A           1   AJT472-1          False
# 4    M9           EcN         1   A           1   AJT472-1           True
# 5    M9           EcN         1   A           1   AJT472-1          False
# 6    M9           EcN         1   A           1   AJT472-1           True
# 7    M9           EcN         1   A           1   AJT472-1          False
# 8    M9           EcN         1   A           1   AJT472-1           True
# 9    M9           EcN         1   A           1   AJT472-1          False

# %%
# should use Debris_Filter_2 if using Gaussian Mixture Model, otherwise Debris_Filter
exp_gated.data.groupby(['Debris_Filter','parent_strain','strain_num', 'media', 'iptg']).size()
# exp2_gated.data.groupby(['Debris_Filter','parent_strain','strain_num', 'media', 'iptg']).size()
# Out:
# Debris_Filter  parent_strain  strain_num  media  iptg
# False          EcN            AJT474      M9     0.0     17847
#                               AJT473-1    M9     0.0     24589
#                               AJT476-1b   M9     0.0      5449
#                               AJT476-2b   M9     0.0      5295
#                               AJT474-1    M9     0.0     19192
#                               AJT472      M9     0.0     20016
#                               AJT476-2a   M9     0.0      4318
#                               AJT476-1a   M9     0.0      4525
#                               AJT472-1    M9     0.0     41715
#                               blank       blank  0.0     47652
#                               AJT473      M9     0.0     18103
# True           EcN            AJT474      M9     0.0     43083
#                               AJT473-1    M9     0.0     41162
#                               AJT476-1b   M9     0.0      2991
#                               AJT476-2b   M9     0.0      4958
#                               AJT474-1    M9     0.0     41195
#                               AJT472      M9     0.0     42986
#                               AJT476-2a   M9     0.0      2601
#                               AJT476-1a   M9     0.0      1372
#                               AJT472-1    M9     0.0     57237
#                               blank       blank  0.0       748
#                               AJT473      M9     0.0     34752
# dtype: int64

# %%
exp_gated_df = exp_gated.data
# exp2_gated_df = exp2_gated.data

filtered  = exp_gated_df[(exp_gated_df['Debris_Filter']==True)&(exp_gated_df['strain_num']!='blank')]
#picked debris filter that looked best qualitatitvely and excluded blank wells

# filtered.head(10)
filtered.tail(10)
# Out:
#             FITC-A  FITC-H         FSC-A    FSC-H  PE-Texas Red-A  \
# 478762  120.900002    86.0  11275.669922  10315.0        8.880000
# 478763  302.250000   180.0  12025.379883  10185.0       -1.480000
# 478764   64.169998    60.0  10339.520508   9504.0       -5.180000
# 478767 -110.669998   125.0  12121.760742  11681.0      -11.840000
# 478769  -95.790001    61.0  12245.000000  14913.0        3.700000
# 478772   22.320000    72.0   9232.730469  11012.0       11.100000
# 478773    0.930000    92.0   7413.360352  10640.0       29.600000
# 478774   63.240002    81.0   5319.860352   8220.0      -39.220001
# 478775   99.510002    89.0  12287.660156  14085.0        2.220000
# 478776    3.720000    65.0   8126.729980   8540.0       11.100000
#
#         PE-Texas Red-H  Pacific Blue-A  Pacific Blue-H         SSC-A    SSC-H  \
# 478762            47.0      134.639999           111.0  30242.669922  28822.0
# 478763            29.0      118.320000            93.0  45030.601562  42260.0
# 478764            38.0       51.000000            70.0  21650.400391  20672.0
# 478767            17.0     -449.819977             2.0  46555.800781  43090.0
# 478769            36.0     -387.600006             8.0  31594.890625  30201.0
# 478772            42.0     -307.019989            10.0  24251.609375  23652.0
# 478773            62.0     -117.299995            62.0  21337.919922  20592.0
# 478774            33.0     -244.799988            45.0  20332.589844  19080.0
# 478775            16.0      -85.680000            52.0  47574.148438  45293.0
# 478776            36.0     -165.239990            20.0  24949.109375  24369.0
#
#                Time col  iptg media parent_strain replicate row  sample_num  \
# 478762  3283.000000   9   0.0    M9           EcN         1   C          23
# 478763  3283.399902   9   0.0    M9           EcN         1   C          23
# 478764  3284.199951   9   0.0    M9           EcN         1   C          23
# 478767  3287.199951   9   0.0    M9           EcN         1   C          23
# 478769  3287.399902   9   0.0    M9           EcN         1   C          23
# 478772  3288.199951   9   0.0    M9           EcN         1   C          23
# 478773  3288.500000   9   0.0    M9           EcN         1   C          23
# 478774  3288.500000   9   0.0    M9           EcN         1   C          23
# 478775  3289.699951   9   0.0    M9           EcN         1   C          23
# 478776  3289.699951   9   0.0    M9           EcN         1   C          23
#
#        strain_num  Debris_Filter
# 478762  AJT476-2b           True
# 478763  AJT476-2b           True
# 478764  AJT476-2b           True
# 478767  AJT476-2b           True
# 478769  AJT476-2b           True
# 478772  AJT476-2b           True
# 478773  AJT476-2b           True
# 478774  AJT476-2b           True
# 478775  AJT476-2b           True
# 478776  AJT476-2b           True

# %% [markdown]
# # Start from here

# %%
## pickle allows you to save an object as binary so it can be re-opened next time without re-running
## all of the code that loaded it

pickle.dump(exp_gated_df, open("pickledata_gated.p", "wb")) # wb is for writing binary
# exp_gated_df = pickle.load(open("pickledata_gated.p", "rb")) # rb is for reading binary

# # pickle.dump(exp2_gated_df, open("pickledata2_gated.p", "wb")) # wb is for writing binary
# exp2_gated_df = pickle.load(open("pickledata2_gated.p", "rb")) # rb is for reading binary

pickle.dump(filtered, open("pickledata_filtered.p", "wb")) # wb is for writing binary
# filtered = pickle.load(open("pickledata_filtered.p", "rb")) # rb is for reading binary

# %% [markdown]
# ## Calculating Medians

# %%
parent = sorted(filtered['parent_strain'].unique()) # get strain numbers in experiment
print(parent)
# Out:
# ['EcN']

# %%
strains = sorted(filtered['strain_num'].unique()) # get strain numbers in experiment
print(strains)
# Out:
# ['AJT472', 'AJT472-1', 'AJT473', 'AJT473-1', 'AJT474', 'AJT474-1', 'AJT476-1a', 'AJT476-1b', 'AJT476-2a', 'AJT476-2b']

# %%
media = sorted(filtered['media'].unique()) # get media used in experiment
print(media)
# Out:
# ['M9']

# %%
data_dict = dict() # initiate dictionary

# make  nested dictionary with medians in it for each condition (media, inducer, concentration, strain)
for s in ['AJT472','AJT473','AJT474']:
    q = filtered.query('strain_num == "{}"'.format(s))
    data_dict[s] = q['FITC-A'].median()
    
data = pd.Series(data_dict)

# %%
# pickle.dump(data, open("data.p", "wb")) # wb is for writing binary

# %%
data_dict
# Out:
# {'AJT472': 1162.5, 'AJT473': 967.2000122070312, 'AJT474': 967.2000122070312}

# %%
# # controls['M9']['EcN'].loc[[~np.isnan(controls['M9']['EcN'].loc[:,'AJT206'])],'AJT206']
# print(controls['M9']['EcN'].loc[:,'AJT206'][~np.isnan(controls['M9']['EcN'].loc[:,'AJT206'])])
# auto = (controls['M9']['EcN'].loc[:,'AJT206'][~np.isnan(controls['M9']['EcN'].loc[:,'AJT206'])]).mean(axis=0)


# # print(controls['M9']['EcN'].loc[:,'AJT280'][~np.isnan(controls['M9']['EcN'].loc[:,'AJT280'])])
# # RPUg = (controls['M9']['EcN'].loc[:,'AJT280'][~np.isnan(controls['M9']['EcN'].loc[:,'AJT280'])]).mean(axis=0)

# %store -r AJT206_auto_store # from 2020-09-22_EcN_Sensors_AllReplicates_v2
# %store -r AJT280_RPUg_store # from 2020-09-22_EcN_Sensors_AllReplicates_v2
auto = AJT206_auto_store
# RPUg = AJT280_RPUg_store

print()
print(auto)
# print(RPUg)
# Out:
# no stored variable # from 2020-09-22_EcN_Sensors_AllReplicates_v2
#
# 33.25156319141388

# %%
data['AJT472']
# Out:
# 1162.5

# %%
# AJT472_r1_au_store = data['AJT472']
# AJT473_r1_au_store = data['AJT473']
# AJT474_r1_au_store = data['AJT474']

# %store AJT472_r1_au_store
# %store AJT473_r1_au_store
# %store AJT474_r1_au_store

# %%
## Histogram-style transfer functions like in Cello SI

data_his_dict = dict() # initiate dictionary

fig_his, ax_his = plt.subplots(1,3, figsize=(7.5,2.5)) # row, column format
plt.tight_layout() #tidies up spacing between plots

strains_subset = ['AJT472','AJT473','AJT474']

for s in strains_subset:
    q = filtered.query('strain_num == "{}"'.format(s))
    data_his_dict[s] = q['FITC-A']
                    
    FP = ax_his[strains_subset.index(s)]

    for spine in FP.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

#                 print(strains_subset.index(s), inducer_info[i]['conc'].index(c))
    logbins = np.geomspace(10,10000,100)
    FP.hist(q['FITC-A'], 
               bins = logbins, 
               orientation='horizontal',
               color = 'darkgray',
               edgecolor = 'darkgray',
               zorder=-1)
    FP.set_yscale('log')
    FP.set_ylim(10,10000)
    FP.tick_params(axis='both',which='both', 
                               bottom=False,top=False,
                               labelbottom=False,
                               right=False,left=False,
                               labelleft=False)
    FP.grid(False)
    FP.set_ylabel('YFP Fluorescence (a.u.)', size=10)
    FP.set_xlabel('Cell count')
    FP.set_title(s, size = 10)
    FP.tick_params(axis='y',which='major',left=True, length=3, width=1, labelleft=True, direction='in')
    FP.tick_params(axis='y',which='minor', left=True, length=1.5, width=1, direction='in')     
    
    xmin, xmax = FP.get_xlim()
    FP.set_xlim(xmin,xmax)
    FP.hlines(data[s],xmin,xmax, linewidth = 0.5)
    FP.text(xmax/4,data[s]/5,'median = {}'.format(round(data[s], 0)), size = 10)

# %%
# fig_his.savefig('RPUconstruct_RelativeExpressionAcrossLPs.pdf', bbox_inches = "tight", transparent = True)
