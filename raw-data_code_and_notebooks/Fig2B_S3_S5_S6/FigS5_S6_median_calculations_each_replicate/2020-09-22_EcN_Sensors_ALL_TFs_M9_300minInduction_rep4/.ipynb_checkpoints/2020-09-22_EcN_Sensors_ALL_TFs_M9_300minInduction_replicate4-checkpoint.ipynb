# %% [markdown]
# # 2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_replicate4

# %% [markdown]
# Brief experiment description:
#
# * OD normalized cells for induction step
# * Testing all sensor promoters for paper, replicate 4
# * Switched back to 1000X inducer stocks for aTc, Nar, OHC14, Van, Cuma (in Adam's specified solvents)
#     - Made 1.5 mL of media and discarded extra 1 mL for total of 0.5 mL in deep-well plate
# * Also testing new 250X inducer stocks for OHC14, Van, Cuma (250X in DMSO)
# * All strains are sequence confirmed
#
# Experimental variables:
# * Circuit landing pad repressor
#     * determined by strain number
# * induction of YFP expression
#     * determined by concentration of inducer
#
# Notes on experiment:
#
# * FITC-A is the output channel (YFP)

# %% [markdown]
# ### Strains
#
# #### Experiment
# | strain number | parent strain | sensor promoter               |       inducer |
# |---------------|---------------|-------------------------------|---------------|
# | AJT269  | EcN | P<sub>tac</sub>      |       IPTG |
# | AJT270  | EcN | P<sub>BAD_mc1</sub>      |       Ara |
# | AJT273  | EcN | P<sub>Tet_org</sub>      |       aTc |
# | AJT274  | EcN | P<sub>Ttg</sub>      |       Nar |
# | AJT275  | EcN | P<sub>Cin</sub>      |       OHC14 |
# | AJT276  | EcN | P<sub>Van</sub>      |       Van |
# | AJT278  | EcN | P<sub>CymRC</sub>      |       Cuma |
#
# #### Controls
# | parent_strain | description               |       strain number |
# |---------------|------------|---------------------|
# | EcN  | all landing pads, sensor integrated, others empty, abx included      |       AJT206 |
# | EcN  | all landing pads, sensor + const. YFP on circuit, abx included      |       AJT280 |

# %% [markdown]
# ### Protocol
#
#  - Overnight in M9 + kan
#  - M9
#      * Dilute 1:150 in 500 uL deep-well plate, grow for 1.5 hours
#      * Dilute to OD = 0.00006667 into 500 uL in deep-well plate with inducers, grow for 5 hours
#          - dilution protocol was pretty solid
#      * 100 uL culture into 200 uL PBS + kan

# %% [markdown]
# ### Inducer concentrations
#
# | Inducer |1|2|3|4|5|6|7|8| Promoter | Strain number |
# | --------|-|-|-|-|-|-|-|-|  ---------| ------------|
# | IPTG |0|5|25|40|50|70|200| 1000 uM| P<sub>tac</sub> | AJT269 |
# | Ara |0|31.25|125|250|500|1000|2000| 4000 uM| P<sub>BAD_mc1</sub> | AJT270 |
# | aTc |0|0.78|1.56|3.12|6.25|12.5|50| 400 uM| P<sub>Tet_org</sub> | AJT273 |
# | Nar |0|0.9765625|3.90625|15.625|31.25|62.5|250| 1000 uM| P<sub>Ttg</sub> | AJT274 |
# |OHC14 |0| 0.01953125|0.0390625|0.078125|0.15625|0.3125|1.25|10 uM| P<sub>Cin</sub> | AJT275 |
# |Van   |0|1.56125|6.25|12.5|25|50|100|200 uM|  P<sub>Van</sub> | AJT276 |
# |Cuma  |0|1.953125|3.90625|7.8125|15.625|31.25|62.5|500 uM| P<sub>CymRC<sub>| AJT278|

# %%
# Matplotlib interactivity
#matplotlib notebook
import matplotlib
matplotlib.rc('figure', dpi = 160)
matplotlib.rcParams['pdf.fonttype'] = 42 # for making font editable when exported to PDF for Illustrator
matplotlib.rcParams['ps.fonttype'] = 42 # for making font editable when exported to PS for Illustrator

# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
import cytoflow as flow
import string
import pandas as pd
import pickle
from scipy.optimize import least_squares
from matplotlib.lines import Line2D

# Dan's custom scripts that aid in importing from conditions.csv file
sys.path.append('/Users/atriassi/Documents/MIT Dropbox (local)/Voigt Lab/_Data/Flow Cytometry Data/cytoflow_example_fromDan/modules')
import cf_imports
import cf_helpers

# %%
# Import reloads for when modules are being changed
import importlib
importlib.reload(cf_imports)
importlib.reload(cf_helpers)
# Out:
# <module 'cf_helpers' from '/Users/atriassi/Documents/MIT Dropbox (local)/Voigt Lab/_Data/Flow Cytometry Data/cytoflow_example_fromDan/modules/cf_helpers.py'>

# %% [markdown]
# ## Data Import

# %%
# Provide full path to flow cytometry .fcs file directory and pass to fixer
fcs_dir = cf_imports.dir_fix(
    r'/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4')
# Optional specification of conditions directory (default to same directory as data)
conds_dir = None

# Provide full path to flow cytometry .fcs file directory and pass to fixer
fcs_dir2 = cf_imports.dir_fix(
    r'/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4')
# Optional specification of conditions directory (default to same directory as data)
conds_dir2 = None

# %%
# Create experiment from fcs files and conditions file ()
exp = cf_imports.exp_from_dirs(fcs_dir, conds_dir)
exp2 = cf_imports.exp_from_dirs(fcs_dir2, conds_dir2)
# Out:
# ['/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A1_A01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A2_A02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A3_A03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A4_A04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A5_A05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A6_A06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A7_A07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A8_A08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A9_A09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_A10_A10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B1_B01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B2_B02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B3_B03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B4_B04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B5_B05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B6_B06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B7_B07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B8_B08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B9_B09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_B10_B10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C1_C01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C2_C02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C3_C03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C4_C04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C5_C05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C6_C06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C7_C07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C8_C08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C9_C09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_C10_C10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D1_D01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D2_D02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D3_D03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D4_D04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D5_D05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D6_D06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D7_D07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D8_D08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D9_D09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_D10_D10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E1_E01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E2_E02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E3_E03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E4_E04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E5_E05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E6_E06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E7_E07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E8_E08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E9_E09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_E10_E10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F1_F01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F2_F02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F3_F03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F4_F04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F5_F05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F6_F06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F7_F07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F8_F08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F9_F09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_F10_F10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G1_G01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G2_G02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G3_G03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G4_G04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G5_G05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G6_G06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G7_G07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G8_G08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G9_G09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_G10_G10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H1_H01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H2_H02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H3_H03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H4_H04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H5_H05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H6_H06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H7_H07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H8_H08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H9_H09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Ptac_Pbad_Ptet_Pttg_AJT269_AJT270_AJT273_AJT274_TFs_rep4/Specimen_001_H10_H10.fcs']
# ['/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A1_A01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A2_A02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A3_A03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A4_A04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A5_A05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A6_A06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A7_A07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A8_A08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A9_A09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A10_A10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A11_A11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_A12_A12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B1_B01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B2_B02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B3_B03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B4_B04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B5_B05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B6_B06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B7_B07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B8_B08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B9_B09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B10_B10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B11_B11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_B12_B12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C1_C01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C2_C02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C3_C03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C4_C04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C5_C05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C6_C06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C7_C07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C8_C08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C9_C09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C10_C10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C11_C11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_C12_C12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D1_D01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D2_D02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D3_D03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D4_D04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D5_D05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D6_D06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D7_D07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D8_D08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D9_D09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D10_D10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D11_D11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_D12_D12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E1_E01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E2_E02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E3_E03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E4_E04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E5_E05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E6_E06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E7_E07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E8_E08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E9_E09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E10_E10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E11_E11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_E12_E12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F1_F01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F2_F02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F3_F03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F4_F04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F5_F05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F6_F06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F7_F07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F8_F08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F9_F09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F10_F10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F11_F11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_F12_F12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G1_G01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G2_G02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G3_G03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G4_G04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G5_G05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G6_G06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G7_G07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G8_G08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G9_G09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G10_G10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G11_G11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_G12_G12.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H1_H01.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H2_H02.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H3_H03.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H4_H04.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H5_H05.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H6_H06.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H7_H07.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H8_H08.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H9_H09.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H10_H10.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H11_H11.fcs',
#  '/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry '
#  'Data/2020-09-22_EcN_Sensors_ALL_TFs_M9_300minInduction_rep4/2020-09-22_EcN_Sensors_Pcin_Pvan_Pcym_AJT275_AJT276_AJT278_TFs_rep4/Specimen_001_H12_H12.fcs']

# %%
# Check dataframe 
exp2.data.head(10)
# Out:
#         FITC-A  FITC-H          FSC-A     FSC-H  PE-Texas Red-A  \
# 0  -103.230003    46.0     466.100006    2018.0      -21.460001
# 1   -12.090000    80.0   16056.750000   14205.0       -3.700000
# 2    -9.300000    56.0    8911.200195    8596.0      -15.540000
# 3   -26.040001    55.0    7964.780273    9642.0       11.100000
# 4    61.380001    65.0    6183.330078    5788.0        8.880000
# 5    94.860001    65.0    7632.190430    7052.0        9.620000
# 6    79.980003   115.0    4656.260254    3966.0       29.600000
# 7    19.530001    78.0   10463.549805   11154.0        5.180000
# 8  1547.520020  1076.0  229441.281250  136217.0       42.920002
# 9   202.740005   212.0   52650.339844   43641.0      -28.120001
#
#    PE-Texas Red-H  Pacific Blue-A  Pacific Blue-H          SSC-A     SSC-H  \
# 0             3.0     -117.419998            23.0    1142.969971    1034.0
# 1             2.0      -31.929998            18.0   56208.269531   52221.0
# 2            10.0      -45.320000            58.0   20978.009766   20432.0
# 3            13.0      -72.099998            16.0   24751.949219   24519.0
# 4            11.0       42.230000            59.0   29070.871094   28497.0
# 5            29.0       -1.030000            48.0   47297.011719   43205.0
# 6            27.0      -52.529999            75.0   63419.492188   51139.0
# 7            19.0       12.360000            39.0   28796.519531   27962.0
# 8            43.0      450.109985           268.0  262143.000000  256506.0
# 9            30.0       86.519997            71.0  157346.703125  129252.0
#
#     ...     media ohc14  ohc14_dmso  parent_strain replicate  row  sample_num  \
# 0   ...        M9   0.0         0.0            EcN         4    A           1
# 1   ...        M9   0.0         0.0            EcN         4    A           1
# 2   ...        M9   0.0         0.0            EcN         4    A           1
# 3   ...        M9   0.0         0.0            EcN         4    A           1
# 4   ...        M9   0.0         0.0            EcN         4    A           1
# 5   ...        M9   0.0         0.0            EcN         4    A           1
# 6   ...        M9   0.0         0.0            EcN         4    A           1
# 7   ...        M9   0.0         0.0            EcN         4    A           1
# 8   ...        M9   0.0         0.0            EcN         4    A           1
# 9   ...        M9   0.0         0.0            EcN         4    A           1
#
#   strain_num  van van_dmso
# 0     AJT275  0.0      0.0
# 1     AJT275  0.0      0.0
# 2     AJT275  0.0      0.0
# 3     AJT275  0.0      0.0
# 4     AJT275  0.0      0.0
# 5     AJT275  0.0      0.0
# 6     AJT275  0.0      0.0
# 7     AJT275  0.0      0.0
# 8     AJT275  0.0      0.0
# 9     AJT275  0.0      0.0
#
# [10 rows x 24 columns]

# %%
exp.data.groupby(['parent_strain','strain_num', 'iptg','ara','atc','nar']).size()
exp2.data.groupby(['parent_strain','strain_num', 'ohc14','van','cuma', 'ohc14_dmso','van_dmso','cuma_dmso']).size()
# Out:
# parent_strain  strain_num   ohc14      van        cuma        ohc14_dmso  van_dmso   cuma_dmso
# EcN            AJT278       0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      60400
#                                                   1.953125    0.000000    0.00000    0.000000      60633
#                                                   3.906250    0.000000    0.00000    0.000000      59483
#                                                   7.812500    0.000000    0.00000    0.000000      59023
#                                                   15.625000   0.000000    0.00000    0.000000      58865
#                                                   31.250000   0.000000    0.00000    0.000000      58076
#                                                   62.500000   0.000000    0.00000    0.000000      58383
#                                                   500.000000  0.000000    0.00000    0.000000      59676
#                blank        0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      61593
#                AJT276_dmso  0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      57902
#                                                                           1.56125    0.000000      56720
#                                                                           6.25000    0.000000      57057
#                                                                           12.50000   0.000000      58233
#                                                                           25.00000   0.000000      60077
#                                                                           50.00000   0.000000      61536
#                                                                           100.00000  0.000000      51181
#                                                                           200.00000  0.000000      48732
#                AJT275       0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      61224
#                             0.019531   0.00000    0.000000    0.000000    0.00000    0.000000      60822
#                             0.039062   0.00000    0.000000    0.000000    0.00000    0.000000      59607
#                             0.078125   0.00000    0.000000    0.000000    0.00000    0.000000      59365
#                             0.156250   0.00000    0.000000    0.000000    0.00000    0.000000      59563
#                             0.312500   0.00000    0.000000    0.000000    0.00000    0.000000      59119
#                             1.250000   0.00000    0.000000    0.000000    0.00000    0.000000      58886
#                             10.000000  0.00000    0.000000    0.000000    0.00000    0.000000      58808
#                AJT276       0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      60788
#                                        1.56125    0.000000    0.000000    0.00000    0.000000      58349
#                                        6.25000    0.000000    0.000000    0.00000    0.000000      57710
#                                        12.50000   0.000000    0.000000    0.00000    0.000000      57947
#                                        25.00000   0.000000    0.000000    0.00000    0.000000      58161
#                                        50.00000   0.000000    0.000000    0.00000    0.000000      59151
#                                        100.00000  0.000000    0.000000    0.00000    0.000000      61397
#                                        200.00000  0.000000    0.000000    0.00000    0.000000      65400
#                AJT278_dmso  0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      58494
#                                                                                      1.953125      59292
#                                                                                      3.906250      58227
#                                                                                      7.812500      57903
#                                                                                      15.625000     57835
#                                                                                      31.250000     57885
#                                                                                      62.500000     57488
#                                                                                      500.000000    58526
#                AJT275_dmso  0.000000   0.00000    0.000000    0.000000    0.00000    0.000000      58677
#                                                               0.019531    0.00000    0.000000      58559
#                                                               0.039062    0.00000    0.000000      57866
#                                                               0.078125    0.00000    0.000000      58071
#                                                               0.156250    0.00000    0.000000      57532
#                                                               0.312500    0.00000    0.000000      57240
#                                                               1.250000    0.00000    0.000000      57046
#                                                               10.000000   0.00000    0.000000      57008
# dtype: int64

# %% [markdown]
# ## Gating

# %% [markdown]
# ### FSC / SSC

# %%
scatter = flow.DensityView(
    xchannel = "FSC-H",
    ychannel = "SSC-H",
    yscale = "log",
    xscale = "log")

scatter.plot(exp, ylim=(100,100000))
scatter.plot(exp2, ylim=(100,100000))

# %% [markdown]
# Gate FSC-A / SSC-A w/ Guassian w/ 2 sigma stddeviation

# %%
# g = flow.GaussianMixtureOp(name = "Debris_Filter",
#                            channels = ["FSC-H", "SSC-H"],
#                            scale = {'FSC-H' : 'log',
#                                     'SSC-H' : 'log'},
#                            num_components = 3, # three seems to do better than two for some cases, if not, can just pick the two
#                            sigma = 2)

# g.estimate(exp_LB)
# g.estimate(exp_M9)

# %%
g2 = flow.PolygonOp(name = "Debris_Filter",
                    xchannel = "FSC-H",
                    ychannel = "SSC-H",
                    xscale = 'log',
                    yscale = 'log')

g2.vertices = [(4000, 10000), # bottom left
             (18000, 18000), # bottom right
             (18000, 55000), # top right
             (4000, 35000)] # top left

# %%
# # takes awhile to run this section
# exp_gated_LB = g.apply(exp_LB)
# exp_gated_M9 = g.apply(exp_M9)

# %%
# for polygon gating as opposed to using Gaussian mixture model
exp_gated = g2.apply(exp)
exp2_gated = g2.apply(exp2)

# %%
# takes a minute or two to run
g2.default_view().plot(exp_gated, alpha = 0.002)
g2.default_view().plot(exp2_gated, alpha = 0.002)

# %%
# # also takes awhile to run this section
# g.default_view().plot(exp_gated_LB, alpha = 0.02)
# g.default_view().plot(exp_gated_M9, alpha = 0.02)

# %%
exp_gated.data.head(10)
# Out:
#        FITC-A  FITC-H         FSC-A    FSC-H  PE-Texas Red-A  PE-Texas Red-H  \
# 0  103.230003    58.0  14963.390625  10254.0       17.760000            31.0
# 1   58.590000    64.0  15551.150391   9689.0       24.420000            25.0
# 2  146.009995    53.0  16171.300781   9256.0       21.460001            22.0
# 3    8.370000    72.0  22989.000000  15940.0       10.360001            27.0
# 4  -41.849998    67.0  19140.121094  13502.0       32.560001            42.0
# 5   27.900000    33.0  14951.540039   7852.0      -11.100000             4.0
# 6  -58.590000    45.0  13610.120117   9905.0      -19.980000            14.0
# 7  141.360001    84.0  13678.060547   7817.0        5.920000            39.0
# 8  -53.939999    32.0  13923.750000   7597.0      -37.000000            27.0
# 9  -53.939999    20.0   7245.880371   2941.0      -31.080000            23.0
#
#    Pacific Blue-A  Pacific Blue-H         SSC-A    SSC-H      ...       col  \
# 0       52.529999            76.0  21363.960938  21305.0      ...         1
# 1      113.299995            52.0  21501.599609  21828.0      ...         1
# 2      -48.410000            42.0  30106.890625  29016.0      ...         1
# 3      -62.829998            59.0  23172.810547  23012.0      ...         1
# 4       -3.090000            39.0  35233.980469  33559.0      ...         1
# 5       17.510000            60.0  36551.789062  33064.0      ...         1
# 6       42.230000            58.0  28305.480469  28097.0      ...         1
# 7      -27.809999            35.0  61578.089844  53721.0      ...         1
# 8      -93.729996            31.0  30807.179688  30208.0      ...         1
# 9      -49.439999            55.0   6445.830078   6137.0      ...         1
#
#    iptg  media  nar  parent_strain replicate  row sample_num strain_num  \
# 0   0.0     M9  0.0            EcN         4    A          1     AJT206
# 1   0.0     M9  0.0            EcN         4    A          1     AJT206
# 2   0.0     M9  0.0            EcN         4    A          1     AJT206
# 3   0.0     M9  0.0            EcN         4    A          1     AJT206
# 4   0.0     M9  0.0            EcN         4    A          1     AJT206
# 5   0.0     M9  0.0            EcN         4    A          1     AJT206
# 6   0.0     M9  0.0            EcN         4    A          1     AJT206
# 7   0.0     M9  0.0            EcN         4    A          1     AJT206
# 8   0.0     M9  0.0            EcN         4    A          1     AJT206
# 9   0.0     M9  0.0            EcN         4    A          1     AJT206
#
#   Debris_Filter
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7         False
# 8          True
# 9         False
#
# [10 rows x 23 columns]

# %%
# should use Debris_Filter_2 if using Gaussian Mixture Model, otherwise Debris_Filter
exp_gated.data.groupby(['Debris_Filter','parent_strain','strain_num', 'media', 'iptg','ara', 'atc','nar']).size()
# exp2_gated.data.groupby(['Debris_Filter','parent_strain','strain_num', 'media', 'ohc14','van','cuma', 'ohc14_dmso','van_dmso','cuma_dmso']).size()
# Out:
# Debris_Filter  parent_strain  strain_num  media  iptg    ara      atc     nar
# False          EcN            AJT274      M9     0.0     0.00     0.00    0.000000         8497
#                                                                           0.976562         8159
#                                                                           3.906250        12834
#                                                                           15.625000        8569
#                                                                           31.250000       16046
#                                                                           62.500000        9608
#                                                                           250.000000      11234
#                                                                           1000.000000      3724
#                               AJT273      M9     0.0     0.00     0.00    0.000000        10693
#                                                                   0.78    0.000000        10220
#                                                                   1.56    0.000000        15319
#                                                                   3.12    0.000000        11064
#                                                                   6.25    0.000000        12337
#                                                                   12.50   0.000000        10384
#                                                                   50.00   0.000000        10600
#                                                                   400.00  0.000000        10309
#                               AJT280      M9     0.0     0.00     0.00    0.000000        38189
#                               AJT269      M9     0.0     0.00     0.00    0.000000        13531
#                                                  5.0     0.00     0.00    0.000000        10008
#                                                  15.0    0.00     0.00    0.000000        10528
#                                                  25.0    0.00     0.00    0.000000        10238
#                                                  40.0    0.00     0.00    0.000000        11358
#                                                  70.0    0.00     0.00    0.000000        10091
#                                                  200.0   0.00     0.00    0.000000         9602
#                                                  1000.0  0.00     0.00    0.000000         9166
#                               blank       blank  0.0     0.00     0.00    0.000000        81386
#                               AJT206      M9     0.0     0.00     0.00    0.000000        43711
#                               AJT270      M9     0.0     0.00     0.00    0.000000        10489
#                                                          31.25    0.00    0.000000         9742
#                                                          125.00   0.00    0.000000        10176
#                                                                                           ...
# True           EcN            AJT274      M9     0.0     0.00     0.00    62.500000       46806
#                                                                           250.000000      38614
#                                                                           1000.000000     11838
#                               AJT273      M9     0.0     0.00     0.00    0.000000        46404
#                                                                   0.78    0.000000        46079
#                                                                   1.56    0.000000        44909
#                                                                   3.12    0.000000        45459
#                                                                   6.25    0.000000        45194
#                                                                   12.50   0.000000        45800
#                                                                   50.00   0.000000        45949
#                                                                   400.00  0.000000        46297
#                               AJT280      M9     0.0     0.00     0.00    0.000000       184152
#                               AJT269      M9     0.0     0.00     0.00    0.000000        46753
#                                                  5.0     0.00     0.00    0.000000        46120
#                                                  15.0    0.00     0.00    0.000000        45784
#                                                  25.0    0.00     0.00    0.000000        45680
#                                                  40.0    0.00     0.00    0.000000        45493
#                                                  70.0    0.00     0.00    0.000000        46004
#                                                  200.0   0.00     0.00    0.000000        46165
#                                                  1000.0  0.00     0.00    0.000000        46573
#                               blank       blank  0.0     0.00     0.00    0.000000         5274
#                               AJT206      M9     0.0     0.00     0.00    0.000000       182955
#                               AJT270      M9     0.0     0.00     0.00    0.000000        46628
#                                                          31.25    0.00    0.000000        46090
#                                                          125.00   0.00    0.000000        45770
#                                                          250.00   0.00    0.000000        45554
#                                                          500.00   0.00    0.000000        45806
#                                                          1000.00  0.00    0.000000        45890
#                                                          2000.00  0.00    0.000000        46049
#                                                          4000.00  0.00    0.000000        46448
# Length: 70, dtype: int64

# %%
exp_gated_df = exp_gated.data
exp2_gated_df = exp2_gated.data


filtered  = pd.concat([exp_gated_df[(exp_gated_df['Debris_Filter']==True)&(exp_gated_df['strain_num']!='blank')] , 
                       exp2_gated_df[(exp2_gated_df['Debris_Filter']==True)&(exp2_gated_df['strain_num']!='blank')]])

#picked debris filter that looked best qualitatitvely and excluded blank wells

filtered.tail(10)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#          Debris_Filter       FITC-A  FITC-H         FSC-A    FSC-H  \
# 2870348           True  3539.580078  3392.0  10673.690430  10777.0
# 2870349           True  3387.989990  3242.0   9650.640625  11622.0
# 2870350           True  5634.870117  5395.0  10544.129883   9662.0
# 2870352           True  3170.370117  3302.0  11993.780273  11151.0
# 2870353           True  4950.390137  4759.0  13524.800781  12154.0
# 2870354           True  4481.669922  4328.0  10123.060547  10388.0
# 2870358           True  3547.949951  3369.0  10483.299805  11157.0
# 2870359           True  4050.150146  3876.0   8300.530273   7721.0
# 2870360           True  2677.469971  2659.0   8594.410156   9758.0
# 2870361           True  5261.939941  5256.0   9114.230469  10180.0
#
#          PE-Texas Red-A  PE-Texas Red-H  Pacific Blue-A  Pacific Blue-H  \
# 2870348           -2.22            26.0      -95.790001            51.0
# 2870349           -8.14            27.0     -230.720001            47.0
# 2870350            4.44            18.0      -62.829998            54.0
# 2870352           13.32            37.0     -169.949997            61.0
# 2870353            0.74            35.0     -153.470001            64.0
# 2870354          -11.84            43.0       -9.270000            79.0
# 2870358          -25.16            26.0      160.679993            62.0
# 2870359          -18.50            21.0      -35.020000            57.0
# 2870360          -17.02            22.0       33.989998            54.0
# 2870361          -25.90            19.0     -111.239998            47.0
#
#                 SSC-A    ...     nar  ohc14  ohc14_dmso  parent_strain  \
# 2870348  23621.070312    ...     NaN    0.0         0.0            EcN
# 2870349  27193.201172    ...     NaN    0.0         0.0            EcN
# 2870350  41886.269531    ...     NaN    0.0         0.0            EcN
# 2870352  27188.550781    ...     NaN    0.0         0.0            EcN
# 2870353  30730.919922    ...     NaN    0.0         0.0            EcN
# 2870354  31022.009766    ...     NaN    0.0         0.0            EcN
# 2870358  32068.259766    ...     NaN    0.0         0.0            EcN
# 2870359  29541.451172    ...     NaN    0.0         0.0            EcN
# 2870360  26907.689453    ...     NaN    0.0         0.0            EcN
# 2870361  31535.371094    ...     NaN    0.0         0.0            EcN
#
#         replicate  row  sample_num   strain_num  van  van_dmso
# 2870348         4    H          95  AJT278_dmso  0.0       0.0
# 2870349         4    H          95  AJT278_dmso  0.0       0.0
# 2870350         4    H          95  AJT278_dmso  0.0       0.0
# 2870352         4    H          95  AJT278_dmso  0.0       0.0
# 2870353         4    H          95  AJT278_dmso  0.0       0.0
# 2870354         4    H          95  AJT278_dmso  0.0       0.0
# 2870358         4    H          95  AJT278_dmso  0.0       0.0
# 2870359         4    H          95  AJT278_dmso  0.0       0.0
# 2870360         4    H          95  AJT278_dmso  0.0       0.0
# 2870361         4    H          95  AJT278_dmso  0.0       0.0
#
# [10 rows x 29 columns]

# %% [markdown]
# # Start from here

# %%
## pickle allows you to save an object as binary so it can be re-opened next time without re-running
## all of the code that loaded it

# pickle.dump(exp_gated_df, open("pickledata_gated.p", "wb")) # wb is for writing binary
exp_gated_df = pickle.load(open("pickledata_gated.p", "rb")) # rb is for reading binary


# pickle.dump(exp2_gated_df, open("pickledata2_gated.p", "wb")) # wb is for writing binary
exp2_gated_df = pickle.load(open("pickledata2_gated.p", "rb")) # rb is for reading binary

# pickle.dump(filtered, open("pickledata_filtered.p", "wb")) # wb is for writing binary
filtered = pickle.load(open("pickledata_filtered.p", "rb")) # rb is for reading binary

# %% [markdown]
# ## Calculating Medians

# %%
parent = sorted(filtered['parent_strain'].unique()) # get strain numbers in experiment
print(parent)
# Out:
# ['EcN']

# %%
strains = sorted(filtered['strain_num'].unique()) # get strain numbers in experiment
print(strains)
# Out:
# ['AJT206', 'AJT269', 'AJT270', 'AJT273', 'AJT274', 'AJT275', 'AJT275_dmso', 'AJT276', 'AJT276_dmso', 'AJT278', 'AJT278_dmso', 'AJT280']

# %%
media = sorted(filtered['media'].unique()) # get media used in experiment
print(media)
# Out:
# ['M9']

# %%
# SPECIFY INDUCERS USED IN THIS EXPERIMENT 
# can't get this from conditions.csv because did them as columns with float values instead of having 
# an inducer name column, which helps deal with situations where multiple inducers are added to same well
inducers = ['ara','iptg','atc','cuma_dmso','van_dmso','ohc14_dmso','nar','cuma','van','ohc14'] 

starting_conc = {'iptg': [2.5], 'ara': [15.625],
                 'atc': [0.39], 'nar': [0.48],
                'ohc14': [0.009], 'van': [0.78],
                'cuma': [0.975], 'ohc14_dmso': [0.009],
                'van_dmso': [0.78], 'cuma_dmso': [0.975]}

inducer_info = {'iptg': {'color': '#fbb03b', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['iptg'])]['iptg'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['iptg'] + sorted(filtered[~np.isnan(filtered['iptg'])]['iptg'].unique())[1:],
                        'column': 3}, # make starting concentration not 0

                'ara': {'color': '#016837', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['ara'])]['ara'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['ara'] + sorted(filtered[~np.isnan(filtered['ara'])]['ara'].unique())[1:],
                        'column': 5},
                
               'atc': {'color': '#00ffff', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['atc'])]['atc'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['atc'] + sorted(filtered[~np.isnan(filtered['atc'])]['atc'].unique())[1:],
                        'column': 7}, # make starting concentration not 0

                'nar': {'color': '#0071bb', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['nar'])]['nar'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['nar'] + sorted(filtered[~np.isnan(filtered['nar'])]['nar'].unique())[1:],
                        'column': 9},
                
                'ohc14': {'color': '#00b4ff', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['ohc14'])]['ohc14'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['ohc14'] + sorted(filtered[~np.isnan(filtered['ohc14'])]['ohc14'].unique())[1:],
                        'column': 1}, # make starting concentration not 0

                'van': {'color': '#ff00ff', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['van'])]['van'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['van'] + sorted(filtered[~np.isnan(filtered['van'])]['van'].unique())[1:],
                        'column': 3},
                
                'cuma': {'color': '#ff0000', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['cuma'])]['cuma'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['cuma'] + sorted(filtered[~np.isnan(filtered['cuma'])]['cuma'].unique())[1:],
                        'column': 5},
                
                'ohc14_dmso': {'color': '#00b4ff', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['ohc14_dmso'])]['ohc14_dmso'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['ohc14_dmso'] + sorted(filtered[~np.isnan(filtered['ohc14_dmso'])]['ohc14_dmso'].unique())[1:],
                        'column': 7}, # make starting concentration not 0

                'van_dmso': {'color': '#ff00ff', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['van_dmso'])]['van_dmso'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['van_dmso'] + sorted(filtered[~np.isnan(filtered['van_dmso'])]['van_dmso'].unique())[1:],
                        'column': 9},
                
                'cuma_dmso': {'color': '#ff0000', # color same as from Adam's paper
                        'conc': sorted(filtered[~np.isnan(filtered['cuma_dmso'])]['cuma_dmso'].unique()), # get concentrations for atc
                        'plot_conc': starting_conc['cuma_dmso'] + sorted(filtered[~np.isnan(filtered['cuma_dmso'])]['cuma_dmso'].unique())[1:],
                        'column': 11}
               } # make starting concentration not 0

# print(inducer_info['nar']['plot_conc'])
print(inducer_info)
# Out:
# {'iptg': {'color': '#fbb03b', 'conc': [0.0, 5.0, 15.0, 25.0, 40.0, 70.0, 200.0, 1000.0], 'plot_conc': [2.5, 5.0, 15.0, 25.0, 40.0, 70.0, 200.0, 1000.0], 'column': 3}, 'ara': {'color': '#016837', 'conc': [0.0, 31.25, 125.0, 250.0, 500.0, 1000.0, 2000.0, 4000.0], 'plot_conc': [15.625, 31.25, 125.0, 250.0, 500.0, 1000.0, 2000.0, 4000.0], 'column': 5}, 'atc': {'color': '#00ffff', 'conc': [0.0, 0.78, 1.56, 3.12, 6.25, 12.5, 50.0, 400.0], 'plot_conc': [0.39, 0.78, 1.56, 3.12, 6.25, 12.5, 50.0, 400.0], 'column': 7}, 'nar': {'color': '#0071bb', 'conc': [0.0, 0.9765625, 3.90625, 15.625, 31.25, 62.5, 250.0, 1000.0], 'plot_conc': [0.48, 0.9765625, 3.90625, 15.625, 31.25, 62.5, 250.0, 1000.0], 'column': 9}, 'ohc14': {'color': '#00b4ff', 'conc': [0.0, 0.01953125, 0.0390625, 0.078125, 0.15625, 0.3125, 1.25, 10.0], 'plot_conc': [0.009, 0.01953125, 0.0390625, 0.078125, 0.15625, 0.3125, 1.25, 10.0], 'column': 1}, 'van': {'color': '#ff00ff', 'conc': [0.0, 1.56125, 6.25, 12.5, 25.0, 50.0, 100.0, 200.0], 'plot_conc': [0.78, 1.56125, 6.25, 12.5, 25.0, 50.0, 100.0, 200.0], 'column': 3}, 'cuma': {'color': '#ff0000', 'conc': [0.0, 1.953125, 3.90625, 7.8125, 15.625, 31.25, 62.5, 500.0], 'plot_conc': [0.975, 1.953125, 3.90625, 7.8125, 15.625, 31.25, 62.5, 500.0], 'column': 5}, 'ohc14_dmso': {'color': '#00b4ff', 'conc': [0.0, 0.01953125, 0.0390625, 0.078125, 0.15625, 0.3125, 1.25, 10.0], 'plot_conc': [0.009, 0.01953125, 0.0390625, 0.078125, 0.15625, 0.3125, 1.25, 10.0], 'column': 7}, 'van_dmso': {'color': '#ff00ff', 'conc': [0.0, 1.56125, 6.25, 12.5, 25.0, 50.0, 100.0, 200.0], 'plot_conc': [0.78, 1.56125, 6.25, 12.5, 25.0, 50.0, 100.0, 200.0], 'column': 9}, 'cuma_dmso': {'color': '#ff0000', 'conc': [0.0, 1.953125, 3.90625, 7.8125, 15.625, 31.25, 62.5, 500.0], 'plot_conc': [0.975, 1.953125, 3.90625, 7.8125, 15.625, 31.25, 62.5, 500.0], 'column': 11}}

# %%
# inducer_info_8conc_paper_withdmso = inducer_info
# %store inducer_info_8conc_paper_withdmso
# Out:
# Stored 'inducer_info_8conc_paper_withdmso' (dict)

# %%
# list(filtered[filtered['parent_strain']=='AJT207']['strain_num'].unique())[0]
# Out:
# 'AJT362'

# %%
data_dict = dict() # initiate dictionary
controls_dict = dict() 

# make giant nested dictionary with medians in it for each condition (media, inducer, concentration, strain)
for m in media:
    data_dict[m] = dict()
    controls_dict[m] = dict() # don't include inducer as index since controls don't see inducer
    for i in inducers:
        data_dict[m][i] = dict()
        for p in parent:
            data_dict[m][i][p] = dict()
            controls_dict[m][p] = dict()

            ## grabbing control values for each well of control strain
            for cs in ['AJT206','AJT280']:
                controls_dict[m][p][cs] = dict()
               
                if cs == 'AJT206':
                    well_row = ['A','B','C','D']
                elif cs == 'AJT280':
                    well_row = ['E','F','G','H']
                    
                for w in well_row:
                
                    q = filtered.query('media == "{}"'.format(m) 
    #                                    + ' and ' + 'parent_strain == "{}"'.format(p)
                                       + ' and ' +  'strain_num == "{}"'.format(cs)
                                       + ' and ' + 'row == "{}"'.format(w))
                    controls_dict[m][p][cs][w] = q['FITC-A'].median()
        
        # since not all strains were induced with all inducers (e.g. Pvan was never induced with iptg), 
        # making separate strain lists for each inducer; otherwise, there will be an error that the strain 
        # with inducer condition !=0 doesn't exist (that's my guess anyways)

        # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if (len(filtered[filtered['strain_num']==s][i].unique())>1 and
                                                     s in filtered[filtered['parent_strain']==p]['strain_num'].unique())] # need to separate this way for subtracting autfluorescence later

            for c in inducer_info[i]['conc']:
                data_dict[m][i][p][c] = dict()
                for s in strains_subset:
                    q = filtered.query('media == "{}"'.format(m) 
                                       + ' and ' + '{} == {}'.format(i, c)
#                                        + ' and ' + 'parent_strain == "{}"'.format(p)
                                       + ' and ' +  'strain_num == "{}"'.format(s))
                    data_dict[m][i][p][c][s] = q['FITC-A'].median()

# make dictionary of dataframes beacuse dataframes look nicer
data = dict()
controls = dict()

for m in media:
    data[m] = dict()
    controls[m] = dict()
    for i in inducers:
        data[m][i] = dict()
        for p in parent:
            data[m][i][p] = pd.DataFrame.from_dict(data_dict[m][i][p])
            controls[m][p] = pd.DataFrame.from_dict(controls_dict[m][p])

# %%
# pickle.dump(data, open("data.p", "wb")) # wb is for writing binary

# %%
controls['M9']['EcN']
# Out:
#       AJT206       AJT280
# A  37.200001          NaN
# B  35.340000          NaN
# C  33.480000          NaN
# D  31.620001          NaN
# E        NaN  1039.739990
# F        NaN  1027.650024
# G        NaN  1008.119995
# H        NaN   991.380005

# %%
# %store -r AJT206_auto_store
# %store -r AJT280_RPUg_store

# %%
auto = round(AJT206_auto_store) # from 2020-09-22_EcN_Sensors_AllReplicates_v2
RPUg = AJT280_RPUg_store # from 2020-09-22_EcN_Sensors_AllReplicates_v2

print(auto)
print(RPUg)
# Out:
# 33.0
# 954.3968868255615

# %%
# AJT206_Sensors_r4_store = auto
# AJT280_Sensors_r4_store = RPUg

# %store AJT206_Sensors_r4_store
# %store AJT280_Sensors_r4_store
# Out:
# Stored 'AJT206_Sensors_r4_store' (float)
# Stored 'AJT280_Sensors_r4_store' (float)

# %%
data['M9']['ohc14']['EcN']
# Out:
#         0.000000   0.019531   0.039062    0.078125     0.156250     0.312500   \
# AJT275      34.41      36.27  60.450001  200.880005  1246.199951  2342.669922
#
#           1.250000     10.000000
# AJT275  3061.560059  3569.340088

# %%
data['M9']['ohc14_dmso']['EcN']
# Out:
#              0.000000   0.019531    0.039062    0.078125     0.156250   \
# AJT275_dmso  31.620001  38.130001  174.839996  771.900024  1894.410034
#
#                0.312500     1.250000     10.000000
# AJT275_dmso  2858.820068  3496.800049  3996.209961

# %%
# AJT269_ODnorm_r4_au_store = data['M9']['iptg']['EcN'].loc['AJT269']
# AJT270_ODnorm_r4_au_store = data['M9']['ara']['EcN'].loc['AJT270']
# AJT273_ODnorm_r4_au_store = data['M9']['atc']['EcN'].loc['AJT273']
# AJT274_ODnorm_r4_au_store = data['M9']['nar']['EcN'].loc['AJT274']
# AJT275_ODnorm_r4_au_store = data['M9']['ohc14']['EcN'].loc['AJT275']
# AJT276_ODnorm_r4_au_store = data['M9']['van']['EcN'].loc['AJT276']
# AJT278_ODnorm_r4_au_store = data['M9']['cuma']['EcN'].loc['AJT278']
# AJT275_ODnorm_dmso_r2_au_store = data['M9']['ohc14_dmso']['EcN'].loc['AJT275_dmso']
# AJT276_ODnorm_dmso_r2_au_store = data['M9']['van_dmso']['EcN'].loc['AJT276_dmso']
# AJT278_ODnorm_dmso_r2_au_store = data['M9']['cuma_dmso']['EcN'].loc['AJT278_dmso']

# %store AJT269_ODnorm_r4_au_store
# %store AJT270_ODnorm_r4_au_store
# %store AJT273_ODnorm_r4_au_store
# %store AJT274_ODnorm_r4_au_store
# %store AJT275_ODnorm_r4_au_store
# %store AJT276_ODnorm_r4_au_store
# %store AJT278_ODnorm_r4_au_store
# %store AJT275_ODnorm_dmso_r2_au_store
# %store AJT276_ODnorm_dmso_r2_au_store
# %store AJT278_ODnorm_dmso_r2_au_store
# Out:
# Stored 'AJT269_ODnorm_r4_au_store' (Series)
# Stored 'AJT270_ODnorm_r4_au_store' (Series)
# Stored 'AJT273_ODnorm_r4_au_store' (Series)
# Stored 'AJT274_ODnorm_r4_au_store' (Series)
# Stored 'AJT275_ODnorm_r4_au_store' (Series)
# Stored 'AJT276_ODnorm_r4_au_store' (Series)
# Stored 'AJT278_ODnorm_r4_au_store' (Series)
# Stored 'AJT275_ODnorm_dmso_r2_au_store' (Series)
# Stored 'AJT276_ODnorm_dmso_r2_au_store' (Series)
# Stored 'AJT278_ODnorm_dmso_r2_au_store' (Series)

# %%
# dictionary with strain information that can be copied from experiment to experiment
strain_info = dict([('AJT206', {'color': 'k', 
                                'promoter': 'none',
                                'inducer': 'none'}), 
                      ('AJT280',{'color': 'k', 
                                 'promoter': 'RPU',
                                'inducer': 'none'}),
                      ('AJT269',{'color': '#fbb03b', 
                                 'promoter': '$P_{Tac}$',
                                'inducer': 'iptg'}),
                      ('AJT270',{'color': '#016837', 
                                 'promoter': '$P_{BAD_{mc1}}$',
                                'inducer': 'ara'}),
                      ('AJT271',{'color': '#016837', 
                                 'promoter': '$P_{BAD_{mc}}$',
                                'inducer': 'ara'}),
                      ('AJT272',{'color': '#00ffff', 
                                 'promoter': '$P_{Tet_{D18}}$',
                                'inducer': 'aTc'}),
                      ('AJT273',{'color': '#00ffff', 
                                 'promoter': '$P_{Tet_{Org}}$',
                                'inducer': 'aTc'}),
                      ('AJT274',{'color': '#0071bb', 
                                'promoter': '$P_{Ttg_{v1}}$',
                                 'inducer': 'nar'}),
                      ('AJT275',{'color': '#00b4ff', 
                                'promoter': '$P_{Cin}$',
                                'inducer': 'ohc14'}),
                      ('AJT276',{'color': '#ff00ff', 
                                 'promoter': '$P_{Van_{v2}}$',
                                'inducer': 'van'}),
                      ('AJT277',{'color': '#ff0000', 
                                'promoter': '$P_{CymRC_{v1}}$',
                                'inducer': 'cuma'}),
                      ('AJT278',{'color': '#ff0000', 
                                 'promoter': '$P_{CymRC_{v2}}$',
                                'inducer': 'cuma'}),
                      ('AJT279',{'color': '#ff00ff', 
                                 'promoter': '$P_{Van_{v1}}$',
                                'inducer': 'van'}),
                    ('AJT275_dmso',{'color': '#00b4ff', 
                                'promoter': '$P_{Cin}$',
                                'inducer': 'ohc14_dmso',
                               'parent': 'EcN'}),
                      ('AJT276_dmso',{'color': '#ff00ff', 
                                 'promoter': '$P_{Van_{v2}}$',
                                'inducer': 'van_dmso',
                               'parent': 'EcN'}),
                      ('AJT278_dmso',{'color': '#ff0000', 
                                 'promoter': '$P_{CymRC_{v2}}$',
                                'inducer': 'cuma_dmso',
                               'parent': 'EcN'}),
                    
                      ('AJT361',{'color': 'k', 
                                 'promoter': 'none',
                                'inducer': 'none'}),
                      ('AJT374',{'color': 'k',
                                'promoter': 'none',
                                'inducer':'none'}),
                      ('AJT367',{'color': '#fbb03b', 
                                 'promoter': '$P_{Tac}$',
                                'inducer': 'iptg'}),
                      ('AJT368',{'color': '#016837', 
                                 'promoter': '$P_{BAD_{mc1}}$',
                                'inducer': 'ara'}),
                      ('AJT369',{'color': '#00ffff', 
                                 'promoter': '$P_{Tet_{Org}}$',
                                'inducer': 'aTc'}),
                      ('AJT370',{'color': '#0071bb', 
                                'promoter': '$P_{Ttg_{v1}}$',
                                 'inducer': 'nar'}),
                      ('AJT371',{'color': '#00b4ff', 
                                'promoter': '$P_{Cin}$',
                                'inducer': 'ohc14'}),
                      ('AJT372',{'color': '#ff00ff', 
                                 'promoter': '$P_{Van_{v2}}$',
                                'inducer': 'van'}),
                      ('AJT373',{'color': '#ff0000', 
                                 'promoter': '$P_{CymRC_{v2}}$',
                                'inducer': 'cuma'}),

                    
                      ('AJT362',{'color': 'k', 
                                 'promoter': 'none',
                                'inducer': 'none'}),
                      ('AJT382',{'color': 'k',
                                'promoter': 'none',
                                'inducer':'none'}),
                      ('AJT375',{'color': '#fbb03b', 
                                 'promoter': '$P_{Tac}$',
                                'inducer': 'iptg'}),
                      ('AJT376',{'color': '#016837', 
                                 'promoter': '$P_{BAD_{mc1}}$',
                                'inducer': 'ara'}),
                      ('AJT377',{'color': '#00ffff', 
                                 'promoter': '$P_{Tet_{Org}}$',
                                'inducer': 'aTc'}),
                      ('AJT378',{'color': '#0071bb', 
                                'promoter': '$P_{Ttg_{v1}}$',
                                 'inducer': 'nar'}),
                      ('AJT379',{'color': '#00b4ff', 
                                'promoter': '$P_{Cin}$',
                                'inducer': 'ohc14'}),
                      ('AJT380',{'color': '#ff00ff', 
                                 'promoter': '$P_{Van_{v2}}$',
                                'inducer': 'van'}),
                      ('AJT381',{'color': '#ff0000', 
                                 'promoter': '$P_{CymRC_{v2}}$',
                                'inducer': 'cuma'}),                    
                   ])

# print(strain_info['AJT275']['promoter'])

# promoters =[]
# for s in strains : # excludes AJT206 and AJT280; could do this a better way than by using these indexes
#     promoters.append(strain_info[s]['promoter'])
    
# print(promoters)

# %%
# dictionary with strain information that can be copied from experiment to experiment

# PsrA = '#d33dc1'
# HlyIIR = '#d2aa85'
# B3BM3R1 = '#44a8c3'
# AmtR = '#32a87c'
# QacR = '#c83832'
# LitR = '#f79a7a'
# AmeR = '#fd4131'
# IcaR = '#6a86c5'
# BetI = '#960985'
# PhlF = '#7bc229'

strain_info_rep = dict([
    ('AJT206', {'color': 'k',
                'repressor': 'none'}),
    ('AJT280',{'color': 'k',
               'repressor': 'RPU'}),
    ('AJT303',{'color': '#d33dc1',
               'repressor': 'PsrA'}),
    ('AJT304',{'color': '#d2aa85',
               'repressor': 'HlyIIR'}),
    ('AJT305',{'color': '#44a8c3',
               'repressor': 'B3BM3R1'}),
    ('AJT306',{'color': '#32a87c',
               'repressor': 'AmtR'}),
    ('AJT307',{'color': '#c83832',
               'repressor': 'QacR'}),
    ('AJT308',{'color': '#f79a7a',
               'repressor': 'LitR'}),
    ('AJT309',{'color': '#fd4131',
               'repressor': 'AmeR'}),
    ('AJT310',{'color': '#6a86c5',
               'repressor': 'IcaR'}),
    ('AJT311',{'color': '#960985',
               'repressor': 'BetI'}),
    ('AJT312',{'color': '#7bc229',
               'repressor': 'PhlF'}),
    ('AJT344', {'color': '#6a86c5',
               'repressor': 'IcaR'}),
    ('AJT269',{'color': '#fbb03b',
               'repressor': '$P_{Tac}$'})
])

# %%
fig_pos = dict()

for m in media:
    fig_pos[m] = dict()
#     strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']
#     for s in strains_subset:
#         fig_pos[m][s] = {'fig_row': strains_subset.index(s)//3, 'fig_col': strains_subset.index(s)-(3*(strains_subset.index(s)//3))}
    for i in inducers:
        fig_pos[m][i] = {'fig_row': inducers.index(i)//4, 'fig_col': inducers.index(i)-(4*(inducers.index(i)//4))}

fig_pos
# Out:
# {'M9': {'ara': {'fig_row': 0, 'fig_col': 0},
#   'iptg': {'fig_row': 0, 'fig_col': 1},
#   'atc': {'fig_row': 0, 'fig_col': 2},
#   'cuma_dmso': {'fig_row': 0, 'fig_col': 3},
#   'van_dmso': {'fig_row': 1, 'fig_col': 0},
#   'ohc14_dmso': {'fig_row': 1, 'fig_col': 1},
#   'nar': {'fig_row': 1, 'fig_col': 2},
#   'cuma': {'fig_row': 1, 'fig_col': 3},
#   'van': {'fig_row': 2, 'fig_col': 0},
#   'ohc14': {'fig_row': 2, 'fig_col': 1}}}

# %% [markdown]
# ## Plot transfer function (no autofluorescence subtracted)

# %%
# Jai's fancy script that contains a class that builds transfer functions
## path for it in terminal open -a Sublime\ Text transferfunction.py

# %load_ext autoreload
# %autoreload # to make sure that it reloads properly when this is run
sys.path.append('/Users/atriassi/Dropbox (Personal)')
from transferfunction_beta import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## plot transfer function (no autofluorescence subtracted)

rows = 3
cols = 4

fig, ax = plt.subplots(rows,cols, figsize=(cols*7.5,rows*7.5)) # row, column format
plt.tight_layout(pad = 4, h_pad = 12, w_pad = 12) #tidies up spacing between plots

# ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
# for spine in ax.spines.values():
#     spine.set_edgecolor('k')

tfs = dict() # dictionary that eventually contains transfer function information

for m in media:
    tfs[m] = dict()
    
    for i in inducers:
        tfs[m][i] = dict()
        for p in parent:
            tfs[m][i][p] = dict()
            # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if (len(filtered[filtered['strain_num']==s][i].unique())>1 and
                                                     s in filtered[filtered['parent_strain']==p]['strain_num'].unique())] # need to separate this way for subtracting autfluorescence later

            for s in strains_subset:
                if s != 'AJT206' and s != 'AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382': # exclude these because I don't need them
                    
                    FP = ax[fig_pos[m][i]['fig_row']][fig_pos[m][i]['fig_col']]
                    
                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in FP.spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(2)
                        
                    tfs[m][i][p][s] = build_transfer_functions([inducer_info[i]['plot_conc']], # x data
                                                      [data[m][i][p].loc[s].tolist()], # y data; needs to be a list for Jai's stuff
                                                      ['{} in {} ({})'.format(strain_info[s]['promoter'], list(filtered[filtered['strain_num']==s]['parent_strain'].unique())[0], s)], # name of transfer function                
                                                               'activator') #kind
                    ## scatter
                    # have to get data from tfs[m][i] as [0] because it is a list of lists, which in this case is only 1 list
                    # .inputs and .outputs notation is from Jai's script, which creates objects from what was fed to tf builder
                    FP.scatter(tfs[m][i][p][s][0].inputs, tfs[m][i][p][s][0].outputs,
                                                                s = 200, zorder=2, c = strain_info[s]['color'],
                                                                edgecolors = 'k', linewidths = 2)

                    ## fitting line
                    xvals = np.logspace(np.log10(inducer_info[i]['plot_conc'][0]),np.log10(inducer_info[i]['plot_conc'][-1]), 1000) # x values for creating smooth line

                    # tfs[m][i][0].hill_eqn(xvals) outputs y values for hill equation at many x values; 
                    # uses fit parameters from build_transfer_functions module above
                    FP.plot(xvals, tfs[m][i][p][s][0].hill_eqn_act(xvals), 
                                                                                   color = strain_info[s]['color'],
                                                                                   zorder = 1, linewidth = 2)

                    FP.set_yscale('log')
                    FP.set_xscale('log')
                    FP.set_ylabel('YFP Fluorescence (au)', size = 24)
                    FP.set_xlabel('[{}] (uM)'.format(i), size = 24)
                    
                    if i == 'atc':
                        FP.set_xlabel('[{}] (nM)'.format(i), size = 24)
                    
                    FP.set_title(tfs[m][i][p][s][0].name, size = 24, pad = 10)

#                     # scatter
#                     ax[fig_pos[m][s]['fig_col']].scatter(inducer_info[i]['plot_conc'], 
#                                     data[m][i][p].loc[s], s = 200, zorder=2, c = strain_info[s]['color'], 
#                                     edgecolors = 'k', linewidths = 2)

#                     ax[fig_pos[m][s]['fig_col']].set_yscale('log')
#                     ax[fig_pos[m][s]['fig_col']].set_xscale('log')
#                     ax[fig_pos[m][s]['fig_col']].set_ylabel('YFP Fluorescence (au)', size = 24)
#                     ax[fig_pos[m][s]['fig_col']].set_xlabel('[{}] (uM)'.format(i), size = 24)
#                     ax[fig_pos[m][s]['fig_col']].set_title('{} in {} ({})'.format(strain_info[s]['promoter'],
#                                                                                   list(filtered[filtered['strain_num']==s]['parent_strain'].unique())[0], s), 
#                                                                                    size = 24)
                    FP.tick_params(labelsize = 24, length = 10, width = 2, direction = 'in', pad = 10)
                    FP.tick_params(which='minor', length = 5, width = 2, direction = 'in')
                    FP.set_ylim(10,10000)
                    FP.set_xlim(inducer_info[i]['plot_conc'][0],inducer_info[i]['plot_conc'][-1])

                    FP.yaxis.grid(True)
                    FP.xaxis.grid(True)
                    
        #             ax[fig_pos[m][i]['fig_row']][fig_pos[m][i]['fig_col']].set_xticks(range(len(promoters)+1))
    #                 ax[fig_pos[m][i]['fig_row']][fig_pos[m][i]['fig_col']].set_xticklabels(inducer_info[i]['conc'])

# %%
# fig.savefig('TF_au.pdf', bbox_inches = "tight", transparent = True)

# %%
# Out:
# 6
# 1.791759469228055
# 0.7781512503836436

# %% [markdown]
# ## Plot histogram-style transfer function (no autofluorescence subtracted)

# %%
## Histogram-style transfer functions like in Cello SI

data_his_dict = dict() # initiate dictionary


fig_his, ax_his = plt.subplots(len(inducers),len(inducer_info[i]['conc']), figsize=(2.5,len(inducers)*2.5)) # row, column format
plt.subplots_adjust(wspace=0) #get rid of horizontal spacing between plots

for m in media:
    data_his_dict[m] = dict()
    for i in inducers:  
        data_his_dict[m][i] = dict()
        for p in parent:
            data_his_dict[m][i][p] = dict()
        
        # since not all strains were induced with all inducers (e.g. Pvan was never induced with iptg), 
        # making separate strain lists for each inducer; otherwise, there will be an error that the strain 
        # with inducer condition !=0 doesn't exist (that's my guess anyways)

        # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]

            for c in inducer_info[i]['conc']:
                data_his_dict[m][i][p][c] = dict()
                
                FP = ax_his[inducers.index(i)][inducer_info[i]['conc'].index(c)]
                
                for s in strains_subset:
                    for spine in FP.spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(1)

                    q = filtered.query('media == "{}"'.format(m) 
                                       + ' and ' + '{} == {}'.format(i, c) 
                                       + ' and ' +  'strain_num == "{}"'.format(s))
                    data_his_dict[m][i][p][c][s] = q['FITC-A']

    #                 print(strains_subset.index(s), inducer_info[i]['conc'].index(c))
                    logbins = np.geomspace(10,20000,200)
                    FP.hist(q['FITC-A'], 
                               bins = logbins, 
                               orientation='horizontal',
                               color = 'darkgray',
                               edgecolor = 'darkgray',
                               zorder=-1)
                    FP.set_yscale('log')
                    FP.set_ylim(10,20000)
                    FP.tick_params(axis='both',which='both', 
                                       bottom=False,top=False,
                                       labelbottom=False,
                                       right=False,left=False,
                                       labelleft=False)
                    FP.grid(False)
                    ax_his[inducers.index(i)][0].set_ylabel('YFP Fluorescence (au)', size=10)
                    # only setting title on middle subplot, needs to be floor division operator to avoid it being a float
                    ax_his[inducers.index(i)][(len(inducer_info[i]['conc'])//2)].set_title('{} ({})'.format(strain_info[s]['promoter'], m), size = 10)
                    ax_his[inducers.index(i)][0].tick_params(axis='y',which='major',left=True, 
                                                                   length=3, width=1, labelleft=True, direction='in')
                    ax_his[inducers.index(i)][0].tick_params(axis='y',which='minor', left=True,
                                                                   length=1.5, width=1, direction='in')     
                
# make dictionary of dataframes beacuse dataframes look nicer
data_his = dict()

for m in media:
    data_his[m] = dict()
    for i in inducers:
        data_his[m][i] = dict()
        for p in parent:
            data_his[m][i][p] = pd.DataFrame.from_dict(data_his_dict[m][i][p])

# %% [markdown]
# ## Subtract autofluorescence

# %%
# make dictionary of dataframes beacuse dataframes look nicer
data_autosub = dict()
autofluor = dict()

for m in media:
    data_autosub[m] = dict()
    autofluor[m] = dict()
    for i in inducers:
        data_autosub[m][i] = dict()
        autofluor[m][i] = dict()
        for p in parent:
#             if p == 'AJT207':
#                 autofluor[m][i][p] = data[m][i][p].loc['AJT362', :]
#             elif p == 'AJT209':
#                 autofluor[m][i][p] = data[m][i][p].loc['AJT361', :]
#             elif p == 'EcN':
#                 autofluor[m][i][p] = data[m][i][p].loc['AJT206', :]
            data_autosub[m][i][p] = data[m][i][p].subtract(auto, axis = 1)
            data_autosub[m][i][p] = data_autosub[m][i][p].mask(data_autosub[m][i][p] <= 0, 0.1)


data_autosub['M9']['ara']['EcN']
# Out:
#           0.00     31.25      125.00      250.00      500.00       1000.00  \
# AJT270  18.150002    23.73  43.260002  124.169998  1438.26001  2490.090088
#
#             2000.00      4000.00
# AJT270  2728.169922  2784.899902

# %%
data['M9']['iptg']['EcN']
# Out:
#            0.0     5.0         15.0        25.0         40.0         70.0    \
# AJT269  49.290001   56.73  102.300003  294.809998  1578.209961  2320.350098
#
#              200.0        1000.0
# AJT269  2913.689941  3396.360107

# %% [markdown]
# ## Plot in RPU (autofluorescence subtracted)

# %%
## Put things in RPU
data_RPU = dict()

for m in media:
    data_RPU[m] = dict()
    for i in inducers:
        data_RPU[m][i] = dict()
        for p in parent:
#             if p == 'AJT207':
#                 data_RPU[m][i][p] = data_autosub[m][i][p].div(data_autosub[m][i][p].loc["AJT382",:], axis = 1)
#             elif p == 'AJT209':
#                 data_RPU[m][i][p] = data_autosub[m][i][p].div(data_autosub[m][i][p].loc["AJT374",:], axis = 1)
            if p == 'EcN':
                data_RPU[m][i][p] = data_autosub[m][i][p].div(RPUg, axis = 1)
data_RPU['M9']['iptg']['EcN']
# Out:
#           0.0       5.0       15.0     25.0      40.0      70.0      200.0   \
# AJT269  0.017068  0.024864  0.072611  0.27432  1.619043  2.396645  3.018335
#
#           1000.0
# AJT269  3.524069

# %%
data_RPU['M9']['ara']['EcN']
# Out:
#          0.00      31.25     125.00    250.00    500.00    1000.00   2000.00  \
# AJT270  0.019017  0.024864  0.045327  0.130103  1.506983  2.609072  2.858528
#
#          4000.00
# AJT270  2.917968

# %%
# AJT269_r1_RPU_store = data_RPU['M9']['iptg']['EcN'].loc['AJT269']
# AJT270_r1_RPU_store = data_RPU['M9']['ara']['EcN'].loc['AJT270']

# %store AJT269_r1_RPU_store
# %store AJT270_r1_RPU_store
# Out:
# Stored 'AJT269_r1_RPU_store' (Series)
# Stored 'AJT270_r1_RPU_store' (Series)

# %% [markdown]
# ## Histogram-style transfer function (RPU)

# %%
## Subtract autofluorescence from histogram data and put in RPU

RNAPflux = 0.029 # RNAP/s-DNA for MG1655 measured in Bin's paper
copy_num = 13.2 # copy number of p15a plasmid in Bin's paper in MG1655
RNAPflux_conv_factor = RNAPflux*copy_num/4970 # 4970 is mean fluorescence (autosubtracted) observed from YFP construct on p15a plasmid in EcN from 2021-01-20-22 (all reps in 2021-01-14_EcN_RelativeExpression_AllReplicates notebook)


# make dictionary of dataframes beacuse dataframes look nicer
data_his_autosub = dict()
data_his_RPU = dict()
autofluor_his = dict()
data_his_RNAP = dict()

for m in media:
    data_his_autosub[m] = dict()
    data_his_RPU[m] = dict()
    autofluor_his[m] = dict()
    data_his_RNAP[m] = dict()
    for i in inducers:
        data_his_autosub[m][i] = dict()
        data_his_RPU[m][i] = dict()
        autofluor_his[m][i] = dict()
        data_his_RNAP[m][i] = dict()
        for p in parent:
#             if p == 'AJT207':
#                 autofluor_his[m][i][p] = data[m][i][p].loc["AJT362", :]
#             elif p == 'AJT209':
#                 autofluor_his[m][i][p] = data[m][i][p].loc["AJT361", :]
#             elif p == 'EcN':
#                 autofluor_his[m][i][p] = data[m][i][p].loc["AJT206", :]
            data_his_autosub[m][i][p] = data_his[m][i][p].subtract(auto, axis = 1)
            strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
#             #### PREVIOUSLY USED TO REASSIGN NEGATIVE NUMBERS, TRYING WITHOUT IT...looks good for what I can tell
#             for c in inducer_info[i]['conc']:                 
#                 for s in strains_subset:
#                     data_his_autosub[m][i][p][c][s].loc[data_his_autosub[m][i][p][c][s].loc[:]<=0] = 0.1
#             ####
    #                 print(data_autosub[m][i].loc["AJT280",c])
#             if p == 'AJT207':
#                 data_his_RPU[m][i][p] = data_his_autosub[m][i][p].divide(data_autosub[m][i][p].loc["AJT382",c])
#             elif p == 'AJT209':
#                 data_his_RPU[m][i][p] = data_his_autosub[m][i][p].divide(data_autosub[m][i][p].loc["AJT374",c])
#             elif p == 'EcN':

            ## NEW WAY OF CALCULATING RNAP FLUX
            data_his_RNAP[m][i][p] = data_his_autosub[m][i][p] * RNAPflux_conv_factor

            ## NEEDED FOR OLD WAY OF CALCULATING RNAP FLUX
            data_his_RPU[m][i][p] = data_his_autosub[m][i][p].divide(RPUg)
#             data_his_RNAP[m][i][p] = data_his_RPU[m][i][p] * RNAPflux * copy_num
#             data_his_RPU[m][i][p] = data_his_RPU[m][i][p].all.clip(0.001) # set minimum RPU value to 0.001

# data_his_autosub['M9']['iptg']

# %%
data_his['M9']['van']['EcN']
# Out:
#                                                 0.00000    \
# AJT276  62583      44.639999
# 62584      33.480000
# 6258...
#
#                                                 1.56125    \
# AJT276  427499    131.130005
# 427500    -13.950000
# 4275...
#
#                                                 6.25000    \
# AJT276  788523     11.160000
# 788524     14.880000
# 7885...
#
#                                                 12.50000   \
# AJT276  1145826     66.029999
# 1145827     26.040001
# 11...
#
#                                                 25.00000   \
# AJT276  1504620     465.000000
# 1504621     572.880005
# ...
#
#                                                 50.00000   \
# AJT276  1863933    1845.119995
# 1863934    1755.839966
# ...
#
#                                                 100.00000  \
# AJT276  2224209    3186.179932
# 2224210    2153.880127
# ...
#
#                                                 200.00000
# AJT276  2576125    3482.850098
# 2576126    3218.729980
# ...

# %%
# data_his_RPU['M9']['iptg']['EcN'][0]['AJT269']

from openpyxl import load_workbook

### Write dictionary of dataframes to separate sheets of the same Excel workbook
book = load_workbook('/Users/atriassi/Dropbox (Personal)/Education/Grad School/*Papers/Triassi_CellSystems_submission_v1/data/figS5_data.xlsx')
writer = pd.ExcelWriter('/Users/atriassi/Dropbox (Personal)/Education/Grad School/*Papers/Triassi_CellSystems_submission_v1/data/figS5_data.xlsx', engine='openpyxl') 
# writer.book = book
# writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

# write final data to data file for publication
for m in media:
    for i in ['ara','iptg','atc','cuma_dmso','van_dmso','ohc14_dmso', 'nar']:  
        for p in parent:
        
            strains_subset = ['AJT270','AJT269','AJT273','AJT278_dmso','AJT276_dmso','AJT275_dmso','AJT274']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
            for c in inducer_info[i]['conc']:
                for s in strains_subset:
                    
                    data_his_RPU[m][i][p][c][s].to_excel(writer, sheet_name='{0}_{1}_RPU'.format(i,c))

                    writer.save()

# %%
fig_hisRPU, ax_hisRPU = plt.subplots(len(inducers),len(inducer_info[i]['conc']), figsize=(2.5,25)) # row, column format
plt.subplots_adjust(wspace=0) #get rid of horizontal spacing between plots

for m in media:
    for i in inducers:  
        for p in parent:

            # since not all strains were induced with all inducers (e.g. Pvan was never induced with iptg), 
            # making separate strain lists for each inducer; otherwise, there will be an error that the strain 
            # with inducer condition !=0 doesn't exist (that's my guess anyways)

            # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
            
            for c in inducer_info[i]['conc']:
                FP = ax_hisRPU[inducers.index(i)][inducer_info[i]['conc'].index(c)]    
            
                for s in strains_subset:
                    
                    for spine in FP.spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(1)

                    logbins = np.geomspace(.001,20,200)
                    FP.hist(data_his_RPU[m][i][p][c][s], 
                                       bins = logbins, 
                                       orientation='horizontal',
                                       color = strain_info[s]['color'],
                                       edgecolor = strain_info[s]['color'],
                                       zorder=-1)
                    
                    FP.set_yscale('log')
                    FP.set_ylim(.001,20)
                    FP.tick_params(axis='both',which='both', 
                                       bottom=False,top=False,
                                       labelbottom=False,
                                       right=False,left=False,
                                       labelleft=False)
                    FP.grid(False)
                    ax_hisRPU[inducers.index(i)][0].set_ylabel('YFP Fluorescence (RPU)', size=10)
                    ax_hisRPU[inducers.index(i)][(len(inducer_info[i]['conc'])//2)].set_title('{} ({})'.format(strain_info[s]['promoter'], m), size = 10)
                    ax_hisRPU[inducers.index(i)][0].tick_params(axis='y',which='major',left=True, 
                                                                   length=3, width=1, labelleft=True, direction='in')
                    ax_hisRPU[inducers.index(i)][0].tick_params(axis='y',which='minor', left=True,
                                                                   length=1.5, width=1, direction='in')

# %%
# fig_hisRPU.savefig('/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2020-08-11_EcN_SymbioflorG4_Pcym-v1and2_AJT277_AJT288_AJT373_TFs_M9_300minInduction/TransferFunctions_Histograms.pdf', bbox_inches = "tight", transparent = True)

# %% [markdown]
# ### Arrange plots better using GridSpec

# %%
# deleted this section because didn't need it since I only had one plot, but keeping section title so I remember I have it in older files
import matplotlib.gridspec as gridspec

# %%
rows = 2
cols = 4

# fig_test = plt.figure(figsize = (15,10))
fig_test = plt.figure(figsize = (8, 8/cols*rows))
# main_grid = gridspec.GridSpec(2,3) # two rows, three columns
main_grid = gridspec.GridSpec(rows, cols, hspace=0.25,wspace=0.25) # one row, two columns

# remove width space from between plots so they are scrunched together like Alec's plot
grid1 = main_grid[0].subgridspec(1,8, wspace=0)
grid2 = main_grid[1].subgridspec(1,8, wspace=0)
grid3 = main_grid[2].subgridspec(1,8, wspace=0)
grid4 = main_grid[3].subgridspec(1,8, wspace=0)
grid5 = main_grid[4].subgridspec(1,8, wspace=0)
grid6 = main_grid[5].subgridspec(1,8, wspace=0)
grid7 = main_grid[6].subgridspec(1,8, wspace=0)

# so grids can be iterated through because main_grid can't for some reason
# grids = [grid1, grid2, grid3, grid4, grid5, grid6]
grids = [grid1, grid2, grid3, grid4, grid5, grid6, grid7]

# list of axes to be created (4 empty lists containing 12 empty lists)
# axes = [[[] for i in range(12)] for j in range(6)]
axes = [[[] for i in range(8)] for j in range(len(grids))]

for m in media:
    for i in ['ara','iptg','atc','cuma_dmso','van_dmso','ohc14_dmso', 'nar']:  
        for p in parent:
        
            strains_subset = ['AJT270','AJT269','AJT273','AJT278_dmso','AJT276_dmso','AJT275_dmso','AJT274']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
            
            for c in inducer_info[i]['conc']:
                # add subplot to figure and assign to axes list of lists
                axes[inducers.index(i)][inducer_info[i]['conc'].index(c)] = fig_test.add_subplot(grids[inducers.index(i)][inducer_info[i]['conc'].index(c)])
                
                FP = axes[inducers.index(i)][inducer_info[i]['conc'].index(c)]

                for s in strains_subset:

                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in axes[inducers.index(i)][inducer_info[i]['conc'].index(c)].spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(1)

                    # make bin boundaries in log space (min, max, # of bins)
                    logbins = np.logspace(np.log10(0.001),np.log10(20), 100)
                    
#                     print(len(data_his_RPU[m][i][p][c][s]))
                    
                    FP.hist(data_his_RPU[m][i][p][c][s],
                                   weights = np.ones(len(data_his_RPU[m][i][p][c][s])) / len(data_his_RPU[m][i][p][c][s]),
                                   bins = logbins, 
                                   orientation='horizontal',
                                   color = strain_info[s]['color'],
                                   edgecolor = strain_info[s]['color'],
                                   zorder=-1)
        
#                     sns.kdeplot(data_his_RPU[m][i][p][c][s],
# #                                 bins = logbins,
#                                 vertical=True,
#                                 bw = 0.01,
# #                                 common_norm = True,
#                                 color = strain_info[s]['color'],
#                                 shade = True,
#                                 linewidth = 1,
#                                 zorder=-1,
#                                 ax = FP,
#                                legend = False)
        
#                     print(FP.get_xlim())
        
                    # to get bottom of axis on right side (to match Alec's plots)
                    FP.invert_xaxis()

                    FP.set_yscale('log')
                    FP.set_ylim(.001,20)

                    # remove tick marks and labels from all plots (add them back to desired plots below)
                    FP.tick_params(axis='both',which='both', 
                                           bottom=False,top=False,
                                           labelbottom=False,
                                           right=False,left=False,
                                           labelleft=False)
                    FP.grid(False)

                    # need this statement because axes[x][6] = [] when loop starts; can't set_title of non-axis
#                     # adds title to each "subplot"
#                     if axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)] != []:
#                         #to add parent strain, needed to access this way because for loop would just fill value with whatever p's current value is instead of the one that corresponds to the strain number 
#                         axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)].set_title('{} ({})'.format(strain_info[s]['promoter'], s), 
#                                                                    size = 7, color = 'k', fontname = 'Arial')

                    # add tick marks, but not labels, to all plots
                    axes[inducers.index(i)][0].tick_params(axis='y',which='major',left=True, 
                                                                   length=3, width=0.5, labelleft=False, direction='in')
                    axes[inducers.index(i)][0].tick_params(axis='y',which='minor', left=True,
                                                                   length=2, width=0.5, direction='in')

                    # change font to Avenir for tick labels
                    for tick in axes[inducers.index(i)][inducer_info[i]['conc'].index(c)].get_yticklabels():
                        tick.set_fontname("Arial")                

                    # Add y_label and tick labels to two plots on left
                    if inducers.index(i) in [0,4]:
                        axes[inducers.index(i)][0].set_ylabel('Output (RPU)', size=7, fontname = 'Arial')
                        axes[inducers.index(i)][0].tick_params(labelleft=True, labelsize = 7)                
    #                 if axes[1][0] !=[]: 
    #                     axes[1][0].set_ylabel('YFP Fluorescence (RPU)', size=20, fontname = 'Avenir')
    #                     axes[1][0].tick_params(labelleft=True, labelsize = 20)

# %%
# fig_test.savefig('TransferFunctions_Histograms.pdf', bbox_inches = "tight", transparent = True)

# %%
rows = 7
cols = 1

# fig_test = plt.figure(figsize = (15,10))
fig_test2 = plt.figure(figsize = (1.32*cols,1.736*rows))
# main_grid = gridspec.GridSpec(2,3) # two rows, three columns
main_grid = gridspec.GridSpec(rows, cols, hspace=0.323,wspace=0) # one row, two columns

# remove width space from between plots so they are scrunched together like Alec's plot
grid1 = main_grid[0].subgridspec(1,8, wspace=0)
grid2 = main_grid[1].subgridspec(1,8, wspace=0)
grid3 = main_grid[2].subgridspec(1,8, wspace=0)
grid4 = main_grid[3].subgridspec(1,8, wspace=0)
grid5 = main_grid[4].subgridspec(1,8, wspace=0)
grid6 = main_grid[5].subgridspec(1,8, wspace=0)
grid7 = main_grid[6].subgridspec(1,8, wspace=0)

# so grids can be iterated through because main_grid can't for some reason
# grids = [grid1, grid2, grid3, grid4, grid5, grid6]
grids = [grid1, grid2, grid3, grid4, grid5, grid6, grid7]

# list of axes to be created (4 empty lists containing 12 empty lists)
# axes = [[[] for i in range(12)] for j in range(6)]
axes2 = [[[] for i in range(8)] for j in range(len(grids))]

for m in media:
    for i in ['ara','iptg','atc','cuma_dmso','van_dmso','ohc14_dmso', 'nar']:  
        for p in parent:
        
            strains_subset = ['AJT270','AJT269','AJT273','AJT278_dmso','AJT276_dmso','AJT275_dmso','AJT274']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
            
            for c in inducer_info[i]['conc']:
                # add subplot to figure and assign to axes list of lists
                axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)] = fig_test2.add_subplot(grids[inducers.index(i)][inducer_info[i]['conc'].index(c)])
                
                FP = axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)]

                for s in strains_subset:

                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)].spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(1)

                    # make bin boundaries in log space (min, max, # of bins)
                    logbins = np.logspace(np.log10(0.001),np.log10(20), 100)
                    
#                     print(len(data_his_RPU[m][i][p][c][s]))
                    
                    FP.hist(data_his_RPU[m][i][p][c][s],
                                   weights = np.ones(len(data_his_RPU[m][i][p][c][s])) / len(data_his_RPU[m][i][p][c][s]),
                                   bins = logbins, 
                                   orientation='horizontal',
                                   color = 'darkgrey',
                                   edgecolor = 'darkgrey',
                                   zorder=-1)
        
#                     sns.kdeplot(data_his_RPU[m][i][p][c][s],
# #                                 bins = logbins,
#                                 vertical=True,
#                                 bw = 0.01,
# #                                 common_norm = True,
#                                 color = strain_info[s]['color'],
#                                 shade = True,
#                                 linewidth = 1,
#                                 zorder=-1,
#                                 ax = FP,
#                                legend = False)
        
#                     print(FP.get_xlim())
        
                    # to get bottom of axis on right side (to match Alec's plots)
                    FP.invert_xaxis()

                    FP.set_yscale('log')
                    FP.set_ylim(0.0006, 30)

                    # remove tick marks and labels from all plots (add them back to desired plots below)
                    FP.tick_params(axis='both',which='both', 
                                           bottom=False,top=False,
                                           labelbottom=False,
                                           right=False,left=False,
                                           labelleft=False)
                    FP.grid(False)

                    # need this statement because axes[x][6] = [] when loop starts; can't set_title of non-axis
#                     # adds title to each "subplot"
#                     if axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)] != []:
#                         #to add parent strain, needed to access this way because for loop would just fill value with whatever p's current value is instead of the one that corresponds to the strain number 
#                         axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)].set_title('{} ({})'.format(strain_info[s]['promoter'], s), 
#                                                                    size = 7, color = 'k', fontname = 'Arial')

                    # add tick marks, but not labels, to all plots
                    axes2[inducers.index(i)][0].tick_params(axis='y',which='major',left=True, 
                                                                   length=3, width=0.5, labelleft=False, direction='in')
                    axes2[inducers.index(i)][0].tick_params(axis='y',which='minor', left=True,
                                                                   length=2, width=0.5, direction='in')

                    # change font to Avenir for tick labels
                    for tick in axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)].get_yticklabels():
                        tick.set_fontname("Arial")                

                    # Add y_label and tick labels
                    axes2[inducers.index(i)][0].set_ylabel('Output (RPU)', size=7, fontname = 'Arial')
                    axes2[inducers.index(i)][0].tick_params(labelleft=True, labelsize = 7)                
    #                 if axes[1][0] !=[]: 
    #                     axes[1][0].set_ylabel('YFP Fluorescence (RPU)', size=20, fontname = 'Avenir')
    #                     axes[1][0].tick_params(labelleft=True, labelsize = 20)

# plt.show()

# %%
# fig_test2.savefig('TransferFunctions_Histograms_onecolumn.pdf', bbox_inches = "tight", transparent = True)
# fig_test2.savefig('FigS5_TransferFunctions_Histograms_onecolumn.pdf', bbox_inches = "tight", transparent = True)

# %%
rows = 7
cols = 1

# fig_test = plt.figure(figsize = (15,10))
fig_test2_RNAP = plt.figure(figsize = (1.32*cols,1.736*rows))
# main_grid = gridspec.GridSpec(2,3) # two rows, three columns
main_grid = gridspec.GridSpec(rows, cols, hspace=0.323,wspace=0) # one row, two columns

# remove width space from between plots so they are scrunched together like Alec's plot
grid1 = main_grid[0].subgridspec(1,8, wspace=0)
grid2 = main_grid[1].subgridspec(1,8, wspace=0)
grid3 = main_grid[2].subgridspec(1,8, wspace=0)
grid4 = main_grid[3].subgridspec(1,8, wspace=0)
grid5 = main_grid[4].subgridspec(1,8, wspace=0)
grid6 = main_grid[5].subgridspec(1,8, wspace=0)
grid7 = main_grid[6].subgridspec(1,8, wspace=0)

# so grids can be iterated through because main_grid can't for some reason
# grids = [grid1, grid2, grid3, grid4, grid5, grid6]
grids = [grid1, grid2, grid3, grid4, grid5, grid6, grid7]

# list of axes to be created (4 empty lists containing 12 empty lists)
# axes = [[[] for i in range(12)] for j in range(6)]
axes2 = [[[] for i in range(8)] for j in range(len(grids))]

for m in media:
    for i in ['ara','iptg','atc','cuma_dmso','van_dmso','ohc14_dmso', 'nar']:  
        for p in parent:
        
            strains_subset = ['AJT270','AJT269','AJT273','AJT278_dmso','AJT276_dmso','AJT275_dmso','AJT274']
            strains_subset = [s for s in strains_subset if len(filtered[filtered['strain_num']==s][i].unique())>1]
            
            for c in inducer_info[i]['conc']:
                # add subplot to figure and assign to axes list of lists
                axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)] = fig_test2_RNAP.add_subplot(grids[inducers.index(i)][inducer_info[i]['conc'].index(c)])
                
                FP = axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)]

                for s in strains_subset:

                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)].spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(1)

                    # make bin boundaries in log space (min, max, # of bins)
                    logbins = np.logspace(np.log10(0.0001),np.log10(3), 100)
                    
#                     print(len(data_his_RPU[m][i][p][c][s]))
                    
                    FP.hist(data_his_RNAP[m][i][p][c][s],
                                   weights = np.ones(len(data_his_RNAP[m][i][p][c][s])) / len(data_his_RNAP[m][i][p][c][s]),
                                   bins = logbins, 
                                   orientation='horizontal',
                                   color = 'darkgrey',
                                   edgecolor = 'darkgrey',
                                   zorder=-1)
        
#                     sns.kdeplot(data_his_RPU[m][i][p][c][s],
# #                                 bins = logbins,
#                                 vertical=True,
#                                 bw = 0.01,
# #                                 common_norm = True,
#                                 color = strain_info[s]['color'],
#                                 shade = True,
#                                 linewidth = 1,
#                                 zorder=-1,
#                                 ax = FP,
#                                legend = False)
        
#                     print(FP.get_xlim())
        
                    # to get bottom of axis on right side (to match Alec's plots)
                    FP.invert_xaxis()

                    FP.set_yscale('log')
                    FP.set_ylim(.0001,3)

                    # remove tick marks and labels from all plots (add them back to desired plots below)
                    FP.tick_params(axis='both',which='both', 
                                           bottom=False,top=False,
                                           labelbottom=False,
                                           right=False,left=False,
                                           labelleft=False)
                    FP.grid(False)

                    # need this statement because axes[x][6] = [] when loop starts; can't set_title of non-axis
#                     # adds title to each "subplot"
#                     if axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)] != []:
#                         #to add parent strain, needed to access this way because for loop would just fill value with whatever p's current value is instead of the one that corresponds to the strain number 
#                         axes[inducers.index(i)][(len(inducer_info[i]['conc'])//2)].set_title('{} ({})'.format(strain_info[s]['promoter'], s), 
#                                                                    size = 7, color = 'k', fontname = 'Arial')

                    # add tick marks, but not labels, to all plots
                    axes2[inducers.index(i)][0].tick_params(axis='y',which='major',left=True, 
                                                                   length=3, width=0.5, labelleft=False, direction='in')
                    axes2[inducers.index(i)][0].tick_params(axis='y',which='minor', left=True,
                                                                   length=2, width=0.5, direction='in')

                    # change font to Avenir for tick labels
                    for tick in axes2[inducers.index(i)][inducer_info[i]['conc'].index(c)].get_yticklabels():
                        tick.set_fontname("Arial")                

                    # Add y_label and tick labels
                    axes2[inducers.index(i)][0].set_ylabel('Output (RNAP/s)', size=7, fontname = 'Arial')
                    axes2[inducers.index(i)][0].tick_params(labelleft=True, labelsize = 7)                
    #                 if axes[1][0] !=[]: 
    #                     axes[1][0].set_ylabel('YFP Fluorescence (RPU)', size=20, fontname = 'Avenir')
    #                     axes[1][0].tick_params(labelleft=True, labelsize = 20)

# plt.show()

# %%
# fig_test2_RNAP.savefig('TransferFunctions_Histograms_RNAP_onecolumn.pdf', bbox_inches = "tight", transparent = True)

# %% [markdown]
# ## RPU Transfer Functions (with curve fit)

# %%
# Jai's fancy script that contains a class that builds transfer functions
## path for it in terminal open -a Sublime\ Text transferfunction.py

# %load_ext autoreload
# %autoreload # to make sure that it reloads properly when this is run
from transferfunction import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## This one is me making Jai's strategy work with how I already have my data


figRPU, axRPU = plt.subplots(1,2, figsize=(15,7.5)) # row, column format
plt.tight_layout(pad = 4, h_pad = 10, w_pad = 12) #tidies up spacing between plots

tfs_RPU = dict() # dictionary that eventually contains transfer function information

for m in media:
    tfs_RPU[m] = dict()
    
    for i in inducers:
        tfs_RPU[m][i] = dict()
        for p in parent:
            tfs_RPU[m][i][p] = dict()
            # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if (len(filtered[filtered['strain_num']==s][i].unique())>1 and
                                                     s in filtered[filtered['parent_strain']==p]['strain_num'].unique())] # need to separate this way for subtracting autfluorescence later

            for s in strains_subset:
                if s != 'AJT206' and s != 'AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382': # exclude these because I don't need them
#                 strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in axRPU[fig_pos[m][s]['fig_col']].spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(2)

                    tfs_RPU[m][i][p][s] = build_transfer_functions([inducer_info[i]['plot_conc']], # x data
                                                      [data_RPU[m][i][p].loc[s].tolist()], # y data; needs to be a list for Jai's stuff
                                                      ['{} in {} ({})'.format(strain_info[s]['promoter'], list(filtered[filtered['strain_num']==s]['parent_strain'].unique())[0], s)]) # name of transfer function                
                    ## scatter
                    # have to get data from tfs[m][i] as [0] because it is a list of lists, which in this case is only 1 list
                    # .inputs and .outputs notation is from Jai's script, which creates objects from what was fed to tf builder
                    axRPU[fig_pos[m][s]['fig_col']].scatter(tfs_RPU[m][i][p][s][0].inputs, tfs_RPU[m][i][p][s][0].outputs,
                                                                            s = 200, zorder=2, c = strain_info[s]['color'],
                                                                            edgecolors = 'k', linewidths = 2)

                    ## fitting line
                    xvals = np.logspace(np.log10(inducer_info[i]['plot_conc'][0]),np.log10(inducer_info[i]['plot_conc'][-1]), 1000) # x values for creating smooth line

                    # tfs[m][i][0].hill_eqn(xvals) outputs y values for hill equation at many x values; 
                    # uses fit parameters from build_transfer_functions module above
                    axRPU[fig_pos[m][s]['fig_col']].plot(xvals, tfs_RPU[m][i][p][s][0].hill_eqn(xvals), 
                                                                                   color = strain_info[s]['color'],
                                                                                   zorder = 1, linewidth = 2)

                    axRPU[fig_pos[m][s]['fig_col']].set_yscale('log')
                    axRPU[fig_pos[m][s]['fig_col']].set_xscale('log')
                    axRPU[fig_pos[m][s]['fig_col']].set_ylabel('YFP Fluorescence (RPU)', size = 24)
                    axRPU[fig_pos[m][s]['fig_col']].set_xlabel('[{}] (uM)'.format(i), size = 24)
                    axRPU[fig_pos[m][s]['fig_col']].set_title(tfs_RPU[m][i][p][s][0].name, size = 24, pad = 10)
                    axRPU[fig_pos[m][s]['fig_col']].tick_params(labelsize = 24, length = 10, width = 2, direction = 'in', pad = 10)
                    axRPU[fig_pos[m][s]['fig_col']].tick_params(which='minor', length = 5, width = 2, direction = 'in')
                    axRPU[fig_pos[m][s]['fig_col']].set_xlim(inducer_info[i]['plot_conc'][0],inducer_info[i]['plot_conc'][-1])
                    axRPU[fig_pos[m][s]['fig_col']].set_ylim(0.001,10)
                    axRPU[fig_pos[m][s]['fig_col']].yaxis.grid(True)
                    axRPU[fig_pos[m][s]['fig_col']].xaxis.grid(False)

# %%
# figRPU.savefig('/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2020-08-20_EcN_Ptac_Pbad_AJT269_AJT270_TFs_M9_300minInduction_replicate1/TransferFunctions_all.pdf', bbox_inches = "tight", transparent = True)

# %%
## This one is me making Jai's strategy work with how I already have my data


figRPU2, axRPU2 = plt.subplots(1,2, figsize=(15,7.5), sharey = 'row') # row, column format
plt.tight_layout(pad = 4, h_pad = 4, w_pad = 4) #tidies up spacing between plots

tfs_RPU = dict() # dictionary that eventually contains transfer function information

for m in media:
    tfs_RPU[m] = dict()
    
    for i in inducers:
        tfs_RPU[m][i] = dict()
        for p in parent:
            tfs_RPU[m][i][p] = dict()
            # chose >1 since if never saw other inducer, there should only be 0 as the inducer concentration from conditions file
            strains_subset = [s for s in strains if (len(filtered[filtered['strain_num']==s][i].unique())>1 and
                                                     s in filtered[filtered['parent_strain']==p]['strain_num'].unique())] # need to separate this way for subtracting autfluorescence later

            for s in strains_subset:
                if s != 'AJT206' and s != 'AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382': # exclude these because I don't need them
#                 strains_subset = [s for s in strains if s!='AJT206' and s!='AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382']                    ## make borders black (https://stackoverflow.com/questions/7778954/elegantly-changing-the-color-of-a-plot-frame-in-matplotlib)
                    for spine in axRPU2[fig_pos[m][s]['fig_col']].spines.values():
                        spine.set_edgecolor('black')
                        spine.set_linewidth(6)

                    tfs_RPU[m][i][p][s] = build_transfer_functions([inducer_info[i]['plot_conc']], # x data
                                                      [data_RPU[m][i][p].loc[s].tolist()], # y data; needs to be a list for Jai's stuff
                                                      ['{} in {} ({})'.format(strain_info[s]['promoter'], list(filtered[filtered['strain_num']==s]['parent_strain'].unique())[0], s)]) # name of transfer function                
                    ## scatter
                    # have to get data from tfs[m][i] as [0] because it is a list of lists, which in this case is only 1 list
                    # .inputs and .outputs notation is from Jai's script, which creates objects from what was fed to tf builder
                    axRPU2[fig_pos[m][s]['fig_col']].scatter(tfs_RPU[m][i][p][s][0].inputs, tfs_RPU[m][i][p][s][0].outputs,
                                                                            s = 100, zorder=2, c = 'black',
                                                                            edgecolors = 'k', linewidths = 2)

                    ## fitting line
                    xvals = np.logspace(np.log10(inducer_info[i]['plot_conc'][0]),np.log10(inducer_info[i]['plot_conc'][-1]), 1000) # x values for creating smooth line

                    # tfs[m][i][0].hill_eqn(xvals) outputs y values for hill equation at many x values; 
                    # uses fit parameters from build_transfer_functions module above
                    axRPU2[fig_pos[m][s]['fig_col']].plot(xvals, tfs_RPU[m][i][p][s][0].hill_eqn(xvals), 
                                                                                   color = strain_info[s]['color'],
                                                                                   zorder = 1, linewidth = 10)

                    axRPU2[fig_pos[m][s]['fig_col']].set_yscale('log')
                    axRPU2[fig_pos[m][s]['fig_col']].set_xscale('log')
                    axRPU2[0].set_ylabel('YFP Fluorescence (RPU)', size = 30, labelpad = 10)
                    axRPU2[fig_pos[m][s]['fig_col']].set_xlabel('[{}] (uM)'.format(i), size = 30, labelpad = 10)
                    axRPU2[fig_pos[m][s]['fig_col']].set_title(tfs_RPU[m][i][p][s][0].name, size = 30, pad = 10)
                    axRPU2[fig_pos[m][s]['fig_col']].tick_params(labelsize = 30, length = 10, width = 2, direction = 'in', pad = 10)
                    axRPU2[fig_pos[m][s]['fig_col']].tick_params(which='minor', length = 5, width = 2, direction = 'in')
                    axRPU2[fig_pos[m][s]['fig_col']].set_xlim(inducer_info[i]['plot_conc'][0],inducer_info[i]['plot_conc'][-1])
                    axRPU2[fig_pos[m][s]['fig_col']].set_ylim(0.001,10)
                    axRPU2[fig_pos[m][s]['fig_col']].yaxis.grid(False)
                    axRPU2[fig_pos[m][s]['fig_col']].xaxis.grid(False)

# %%
# figRPU2.savefig('/Users/atriassi/Dropbox (MIT)/Voigt Lab/_Data/Flow Cytometry Data/2020-08-20_EcN_Ptac_Pbad_AJT269_AJT270_TFs_M9_300minInduction_replicate1/TransferFunctions_all_CAVstyle_darkgrey.pdf', bbox_inches = "tight", transparent = True)

# %% [markdown]
# ## Hill function output parameters

# %% [markdown]
# The following is used for repression equations. x^n goes in the numerator instead of K^n for activation.<br/><br/>
# y = promoter activity in RPU<br/>
# x = concentration of small molecule<br/>
# ymin = leakiness<br/>
# K = threshold (sensitivity)<br/>
# n = cooperativity
#
# $$ y = y_{min} + (y_{max} - y_{min}) * \frac{x^n}{K^n + x^n}$$

# %%
hill_params = dict()
hill_params_df = dict()

for m in media:
    hill_params[m] = dict()
    hill_params_df[m] = dict()
    for i in inducers:
        hill_params[m][i] = dict()
        hill_params_df[m][i] = dict()
        for p in parent:
            hill_params[m][i][p] = dict()
            
            # needed this portion because was pulling strain numbers that weren't corresponding to proper parent strain
            strains_subset = [s for s in strains if (len(filtered[filtered['strain_num']==s][i].unique())>1 and
                                                     s in filtered[filtered['parent_strain']==p]['strain_num'].unique())]
            
            # subset it again to make sure doesn't include white cells or RPU
            strains_subset = [s for s in strains_subset if s!= 'AJT206' and s!= 'AJT280' and s!='AJT361' and s!='AJT362' and s!='AJT374' and s!='AJT382'] # exclude these because I don't need them
            
            for s in strains_subset:
                if i == strain_info[s]['inducer']: # to account for if there is more than one inducer
                    hill_params[m][i][p][s] = ({'Promoter': strain_info[s]['promoter'],
                                     'Max inducer (uM)': round(max(tfs_RPU[m][i][p][s][0].inputs), 1),
                                     'ymax (RPU)' : round(max(tfs_RPU[m][i][p][s][0].outputs),1),
                                     'ymin (RPU * 10^-3)' : round(min(tfs_RPU[m][i][p][s][0].outputs)/(1*10**-3),1),
                                     'K (uM)': round(tfs_RPU[m][i][p][s][0].kd, 1), 
                                     'n': round(tfs_RPU[m][i][p][s][0].n, 1),
                                     'fold-change': round((max(tfs_RPU[m][i][p][s][0].outputs))/(min(tfs_RPU[m][i][p][s][0].outputs)),1)})
            hill_params_df[m][i][p] = pd.DataFrame.from_dict(hill_params[m][i][p], orient = 'index')

# %%
hill_params_df['M9']['iptg']['EcN']
# Out:
#          Promoter  Max inducer (uM)  ymax (RPU)  ymin (RPU * 10^-3)  K (uM)  \
# AJT269  $P_{Tac}$            1000.0         3.4                14.8    41.9
#
#           n  fold-change
# AJT269  3.2        228.4

# %%
hill_params_df['M9']['ara']['EcN']
# Out:
#                Promoter  Max inducer (uM)  ymax (RPU)  ymin (RPU * 10^-3)  \
# AJT270  $P_{BAD_{mc1}}$            4000.0         2.9                16.4
#
#         K (uM)    n  fold-change
# AJT270  1983.2  3.7        174.3
